# %%
import pandas

# %%
research = pandas.read_csv("PhysFit1999.txt",dtype=str,index_col=False)

# %%
research.rename(columns = {'Ccode': 'ccode', 'Dcode':'dcode', 'Scode':'scode', 'charternum':'chrtnum'}, inplace = True)

# %%
research
# Out:
#        Level SubGrp RptType Line_num ccode  dcode    scode        cds_code  \
# 0          4      0       1        1    00  00000  0000000  00000000000000
# 1          4      0       1        2    00  00000  0000000  00000000000000
# 2          4      0       1        3    00  00000  0000000  00000000000000
# 3          4      0       1        4    00  00000  0000000  00000000000000
# 4          4      0       1        5    00  00000  0000000  00000000000000
# ...      ...    ...     ...      ...   ...    ...      ...             ...
# 947822     1     11       2        8    57  72678  6056303  57726786056303
# 947823     1     11       2        8    57  72678  6060396  57726786060396
# 947824     1     11       2        8    57  72678  6066245  57726786066245
# 947825     1     11       2        8    57  72678  6110894  57726786110894
# 947826     1     11       2        8    58  72769  5838305  58727695838305
#
# ...

# %%
oc_research = research.query("`scode` == '0000000' and `dcode` != '00000' and `ccode` == '30' and `Level` == '2' and `RptType` == '1' and `SubGrp` == '0' and (`Line_num` == '1' or `Line_num` == '2')")

# %%
oc_research
# Out:
#      Level SubGrp RptType Line_num ccode  dcode    scode        cds_code  \
# 9080     2      0       1        1    30  66423  0000000  30664230000000
# 9081     2      0       1        1    30  66431  0000000  30664310000000
# 9082     2      0       1        1    30  66449  0000000  30664490000000
# 9083     2      0       1        1    30  66456  0000000  30664560000000
# 9084     2      0       1        1    30  66464  0000000  30664640000000
# 9085     2      0       1        1    30  66472  0000000  30664720000000
# 9086     2      0       1        1    30  66480  0000000  30664800000000
# 9087     2      0       1        1    30  66498  0000000  30664980000000
# 9088     2      0       1        1    30  66506  0000000  30665060000000
# 9089     2      0       1        1    30  66514  0000000  30665140000000
# 9090     2      0       1        1    30  66522  0000000  30665220000000
# 9091     2      0       1        1    30  66530  0000000  30665300000000
# ...

# %%
def weighted_average(df, values, weights):
    d = df[values].astype(float)
    w = df[weights].astype(int)
    return (d * w).sum() / w.sum()

# %%
oc_research.is_copy = False
oc_research.loc[oc_research["Gr5PctIn"] == '*', "Gr5PctIn"] = '0.00 '
oc_research.loc[oc_research["Gr7PctIn"] == '*', "Gr7PctIn"] = '0.00 '
oc_research.loc[oc_research["Gr9PctIn"] == '*', "Gr9PctIn"] = '0.00 '
weighted_5 = str(weighted_average(oc_research, 'Gr5PctIn', 'Gr05_Stu'))
weighted_5
# Out:
# C:\Users\hky\AppData\Local\Temp\ipykernel_20608\1173418962.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oc_research.loc[oc_research["Gr5PctIn"] == '*', "Gr5PctIn"] = '0.00 '
# C:\Users\hky\AppData\Local\Temp\ipykernel_20608\1173418962.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oc_research.loc[oc_research["Gr7PctIn"] == '*', "Gr7PctIn"] = '0.00 '
# C:\Users\hky\AppData\Local\Temp\ipykernel_20608\1173418962.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
oc_research.loc[oc_research["Gr5PctIn"] == '0.00 ', "Gr5PctIn"] = weighted_5
oc_research
# Out:
# C:\Users\hky\AppData\Local\Temp\ipykernel_20608\1411687492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oc_research.loc[oc_research["Gr5PctIn"] == '0.00 ', "Gr5PctIn"] = weighted_5
#      Level SubGrp RptType Line_num ccode  dcode    scode        cds_code  \
# 9080     2      0       1        1    30  66423  0000000  30664230000000
# 9081     2      0       1        1    30  66431  0000000  30664310000000
# 9082     2      0       1        1    30  66449  0000000  30664490000000
# 9083     2      0       1        1    30  66456  0000000  30664560000000
# 9084     2      0       1        1    30  66464  0000000  30664640000000
# 9085     2      0       1        1    30  66472  0000000  30664720000000
# 9086     2      0       1        1    30  66480  0000000  30664800000000
# ...

# %%
weighted_7 = str(weighted_average(oc_research, 'Gr7PctIn', 'Gr07_Stu'))
oc_research.loc[oc_research["Gr7PctIn"] == '0.00 ', "Gr7PctIn"] = weighted_7
weighted_7
# Out:
# C:\Users\hky\AppData\Local\Temp\ipykernel_20608\645041109.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oc_research.loc[oc_research["Gr7PctIn"] == '0.00 ', "Gr7PctIn"] = weighted_7
# '66.98620220739382'

# %%
weighted_9 = str(weighted_average(oc_research, 'Gr9PctIn', 'Gr09_Stu'))
oc_research.loc[oc_research["Gr9PctIn"] == '0.00 ', "Gr9PctIn"] = weighted_9
weighted_9
# Out:
# C:\Users\hky\AppData\Local\Temp\ipykernel_20608\1409511161.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oc_research.loc[oc_research["Gr9PctIn"] == '0.00 ', "Gr9PctIn"] = weighted_9
# '61.59083440308087'

# %%
oc_research.to_csv('oc_result99.csv')
oc_research
# Out:
#      Level SubGrp RptType Line_num ccode  dcode    scode        cds_code  \
# 9080     2      0       1        1    30  66423  0000000  30664230000000
# 9081     2      0       1        1    30  66431  0000000  30664310000000
# 9082     2      0       1        1    30  66449  0000000  30664490000000
# 9083     2      0       1        1    30  66456  0000000  30664560000000
# 9084     2      0       1        1    30  66464  0000000  30664640000000
# 9085     2      0       1        1    30  66472  0000000  30664720000000
# 9086     2      0       1        1    30  66480  0000000  30664800000000
# 9087     2      0       1        1    30  66498  0000000  30664980000000
# 9088     2      0       1        1    30  66506  0000000  30665060000000
# 9089     2      0       1        1    30  66514  0000000  30665140000000
# 9090     2      0       1        1    30  66522  0000000  30665220000000
# 9091     2      0       1        1    30  66530  0000000  30665300000000
# ...
