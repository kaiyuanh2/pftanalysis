# %%
import pandas

# %%
avg = pandas.read_csv("irvine_unified&santaana_unified_district - Sheet1.csv",dtype=float,index_col=False).values.tolist()

# %%
avg
# Out:
# [[1999.0,
#   67.3,
#   67.8,
#   67.9,
#   72.6,
#   76.7,
#   87.2,
#   68.1,
#   67.3,
#   55.0,
#   34.1,
#   20.6,
#   18.4],
#  [2001.0,
#   66.5,
#   67.7,
#   63.8,
#   75.0,
#   82.1,
#   84.3,
#   49.0,
#   54.9,
#   47.1,
#   52.9,
#   58.0,
#   63.4],
#  [2002.0,
#   63.0,
#   71.4,
#   54.4,
#   76.3,
#   82.4,
#   77.3,
#   54.6,
#   54.2,
#   46.9,
#   54.2,
#   58.4,
#   61.1],
#  [2003.0,
#   69.1,
#   75.2,
#   68.5,
#   78.0,
#   82.5,
#   87.0,
#   67.1,
#   65.3,
#   54.7,
#   58.2,
#   59.4,
#   61.2],
#  [2004.0,
#   69.5,
#   74.6,
#   67.9,
#   84.6,
#   84.3,
#   86.4,
#   68.7,
#   64.0,
#   51.4,
#   55.3,
#   59.4,
#   60.7],
#  [2005.0,
#   74.4,
#   82.0,
#   76.8,
#   82.4,
#   86.6,
#   91.1,
#   63.9,
#   61.2,
#   54.6,
#   57.9,
#   57.2,
#   65.5],
#  [2006.0,
#   70.0,
#   85.5,
#   76.2,
#   82.6,
#   86.2,
#   87.2,
#   69.0,
#   61.1,
#   60.4,
#   60.0,
#   59.0,
#   62.3],
#  [2007.0,
#   73.8,
#   86.4,
#   79.8,
#   83.3,
#   82.7,
# ...

# %%
sna_19_ac_avg_5 = avg[19][7]
sna_19_ac_avg_7 = avg[19][8]
sna_19_ac_avg_9 = avg[19][9]
sna_19_bc_avg_5 = avg[19][10]
sna_19_bc_avg_7 = avg[19][11]
sna_19_bc_avg_9 = avg[19][12]
irv_19_ac_avg_5 = avg[19][1]
irv_19_ac_avg_7 = avg[19][2]
irv_19_ac_avg_9 = avg[19][3]
irv_19_bc_avg_5 = avg[19][4]
irv_19_bc_avg_7 = avg[19][5]
irv_19_bc_avg_9 = avg[19][6]

# %%
sna_18_ac_avg_5 = avg[18][7]
sna_18_ac_avg_7 = avg[18][8]
sna_18_ac_avg_9 = avg[18][9]
sna_18_bc_avg_5 = avg[18][10]
sna_18_bc_avg_7 = avg[18][11]
sna_18_bc_avg_9 = avg[18][12]
irv_18_ac_avg_5 = avg[18][1]
irv_18_ac_avg_7 = avg[18][2]
irv_18_ac_avg_9 = avg[18][3]
irv_18_bc_avg_5 = avg[18][4]
irv_18_bc_avg_7 = avg[18][5]
irv_18_bc_avg_9 = avg[18][6]

# %%
sna_17_ac_avg_5 = avg[17][7]
sna_17_ac_avg_7 = avg[17][8]
sna_17_ac_avg_9 = avg[17][9]
sna_17_bc_avg_5 = avg[17][10]
sna_17_bc_avg_7 = avg[17][11]
sna_17_bc_avg_9 = avg[17][12]
irv_17_ac_avg_5 = avg[17][1]
irv_17_ac_avg_7 = avg[17][2]
irv_17_ac_avg_9 = avg[17][3]
irv_17_bc_avg_5 = avg[17][4]
irv_17_bc_avg_7 = avg[17][5]
irv_17_bc_avg_9 = avg[17][6]

# %%
sna_16_ac_avg_5 = avg[16][7]
sna_16_ac_avg_7 = avg[16][8]
sna_16_ac_avg_9 = avg[16][9]
sna_16_bc_avg_5 = avg[16][10]
sna_16_bc_avg_7 = avg[16][11]
sna_16_bc_avg_9 = avg[16][12]
irv_16_ac_avg_5 = avg[16][1]
irv_16_ac_avg_7 = avg[16][2]
irv_16_ac_avg_9 = avg[16][3]
irv_16_bc_avg_5 = avg[16][4]
irv_16_bc_avg_7 = avg[16][5]
irv_16_bc_avg_9 = avg[16][6]

# %%
sna_15_ac_avg_5 = avg[15][7]
sna_15_ac_avg_7 = avg[15][8]
sna_15_ac_avg_9 = avg[15][9]
sna_15_bc_avg_5 = avg[15][10]
sna_15_bc_avg_7 = avg[15][11]
sna_15_bc_avg_9 = avg[15][12]
irv_15_ac_avg_5 = avg[15][1]
irv_15_ac_avg_7 = avg[15][2]
irv_15_ac_avg_9 = avg[15][3]
irv_15_bc_avg_5 = avg[15][4]
irv_15_bc_avg_7 = avg[15][5]
irv_15_bc_avg_9 = avg[15][6]

# %%
sna_14_ac_avg_5 = avg[14][7]
sna_14_ac_avg_7 = avg[14][8]
sna_14_ac_avg_9 = avg[14][9]
sna_14_bc_avg_5 = avg[14][10]
sna_14_bc_avg_7 = avg[14][11]
sna_14_bc_avg_9 = avg[14][12]
irv_14_ac_avg_5 = avg[14][1]
irv_14_ac_avg_7 = avg[14][2]
irv_14_ac_avg_9 = avg[14][3]
irv_14_bc_avg_5 = avg[14][4]
irv_14_bc_avg_7 = avg[14][5]
irv_14_bc_avg_9 = avg[14][6]

# %%
sna_13_ac_avg_5 = avg[13][7]
sna_13_ac_avg_7 = avg[13][8]
sna_13_ac_avg_9 = avg[13][9]
sna_13_bc_avg_5 = avg[13][10]
sna_13_bc_avg_7 = avg[13][11]
sna_13_bc_avg_9 = avg[13][12]
irv_13_ac_avg_5 = avg[13][1]
irv_13_ac_avg_7 = avg[13][2]
irv_13_ac_avg_9 = avg[13][3]
irv_13_bc_avg_5 = avg[13][4]
irv_13_bc_avg_7 = avg[13][5]
irv_13_bc_avg_9 = avg[13][6]

# %%
sna_12_ac_avg_5 = avg[12][7]
sna_12_ac_avg_7 = avg[12][8]
sna_12_ac_avg_9 = avg[12][9]
sna_12_bc_avg_5 = avg[12][10]
sna_12_bc_avg_7 = avg[12][11]
sna_12_bc_avg_9 = avg[12][12]
irv_12_ac_avg_5 = avg[12][1]
irv_12_ac_avg_7 = avg[12][2]
irv_12_ac_avg_9 = avg[12][3]
irv_12_bc_avg_5 = avg[12][4]
irv_12_bc_avg_7 = avg[12][5]
irv_12_bc_avg_9 = avg[12][6]

# %%
sna_11_ac_avg_5 = avg[11][7]
sna_11_ac_avg_7 = avg[11][8]
sna_11_ac_avg_9 = avg[11][9]
sna_11_bc_avg_5 = avg[11][10]
sna_11_bc_avg_7 = avg[11][11]
sna_11_bc_avg_9 = avg[11][12]
irv_11_ac_avg_5 = avg[11][1]
irv_11_ac_avg_7 = avg[11][2]
irv_11_ac_avg_9 = avg[11][3]
irv_11_bc_avg_5 = avg[11][4]
irv_11_bc_avg_7 = avg[11][5]
irv_11_bc_avg_9 = avg[11][6]

# %%
sna_10_ac_avg_5 = avg[10][7]
sna_10_ac_avg_7 = avg[10][8]
sna_10_ac_avg_9 = avg[10][9]
sna_10_bc_avg_5 = avg[10][10]
sna_10_bc_avg_7 = avg[10][11]
sna_10_bc_avg_9 = avg[10][12]
irv_10_ac_avg_5 = avg[10][1]
irv_10_ac_avg_7 = avg[10][2]
irv_10_ac_avg_9 = avg[10][3]
irv_10_bc_avg_5 = avg[10][4]
irv_10_bc_avg_7 = avg[10][5]
irv_10_bc_avg_9 = avg[10][6]

# %%
entities = pandas.read_csv("entitiesoutput19.txt",dtype=str,index_col=False)

# %%
entities_sna = entities.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000'")

# %%
entities_sna
# Out:
#      ccode  dcode chrtnum    scode         cdscode  County           District  \
# 5513    30  66670    0000  0108365  30666700108365  Orange  Santa Ana Unified
# 5514    30  66670    0000  0108373  30666700108373  Orange  Santa Ana Unified
# 5515    30  66670    0000  0114736  30666700114736  Orange  Santa Ana Unified
# 5516    30  66670    0000  0116582  30666700116582  Orange  Santa Ana Unified
# 5517    30  66670    0000  0135897  30666700135897  Orange  Santa Ana Unified
# 5518    30  66670    0000  3030491  30666703030491  Orange  Santa Ana Unified
# 5519    30  66670    0000  3030608  30666703030608  Orange  Santa Ana Unified
# 5520    30  66670    0000  3035821  30666703035821  Orange  Santa Ana Unified
# 5521    30  66670    0000  3036357  30666703036357  Orange  Santa Ana Unified
# 5522    30  66670    0000  3036456  30666703036456  Orange  Santa Ana Unified
# 5523    30  66670    0000  6030209  30666706030209  Orange  Santa Ana Unified
# ...

# %%
entities_irv = entities.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000'")

# %%
entities_irv
# Out:
#      ccode  dcode chrtnum    scode         cdscode  County        District  \
# 5663    30  73650    0000  0127472  30736500127472  Orange  Irvine Unified
# 5664    30  73650    0000  0129155  30736500129155  Orange  Irvine Unified
# 5665    30  73650    0000  0129296  30736500129296  Orange  Irvine Unified
# 5666    30  73650    0000  0133389  30736500133389  Orange  Irvine Unified
# 5667    30  73650    0000  0133405  30736500133405  Orange  Irvine Unified
# 5668    30  73650    0000  0135137  30736500135137  Orange  Irvine Unified
# 5669    30  73650    0000  0136689  30736500136689  Orange  Irvine Unified
# 5670    30  73650    0000  3030152  30736503030152  Orange  Irvine Unified
# 5671    30  73650    0000  3030285  30736503030285  Orange  Irvine Unified
# 5672    30  73650    0000  3030467  30736503030467  Orange  Irvine Unified
# 5673    30  73650    0000  3030657  30736503030657  Orange  Irvine Unified
# ...

# %%
research_19 = pandas.read_csv("researchoutput19.txt",dtype=str,index_col=False)

# %%
research_19.rename(columns = {'CO': 'ccode', 'DIST':'dcode', 'SCHL':'scode', 'ChrtNum':'chrtnum', 'Perc5a':'Perc5a_19', 'Perc7a':'Perc7a_19', 'Perc9a':'Perc9a_19'}, inplace = True)

# %%
research_19_sna_ac = research_19.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")

# %%
research_19_sna_ac
# Out:
#        Level_Number Report_Number Table_Number Line_Number ccode  dcode  \
# 281716            1             0            1           1    30  66670
# 281722            1             0            1           1    30  66670
# 281728            1             0            1           1    30  66670
# 281734            1             0            1           1    30  66670
# 281740            1             0            1           1    30  66670
# 281746            1             0            1           1    30  66670
# 281752            1             0            1           1    30  66670
# 281758            1             0            1           1    30  66670
# 281764            1             0            1           1    30  66670
# 281770            1             0            1           1    30  66670
# 281776            1             0            1           1    30  66670
# 295402            1             0            1           1    30  66670
# ...

# %%
research_19_sna_ac_5 = research_19_sna_ac.query("`Perc5a_19` != '0.0' and `Perc5a_19` != '**'")
research_19_sna_ac_7 = research_19_sna_ac.query("`Perc7a_19` != '0.0' and `Perc7a_19` != '**'")
research_19_sna_ac_9 = research_19_sna_ac.query("`Perc9a_19` != '0.0' and `Perc9a_19` != '**'")

# %%
research_19_sna_ac_5.Perc5a_19 = research_19_sna_ac_5.Perc5a_19.astype(float)
research_19_sna_ac_7.Perc7a_19 = research_19_sna_ac_7.Perc7a_19.astype(float)
research_19_sna_ac_9.Perc9a_19 = research_19_sna_ac_9.Perc9a_19.astype(float)
# Out:
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\412904590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_19_sna_ac_5.Perc5a_19 = research_19_sna_ac_5.Perc5a_19.astype(float)
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\412904590.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_19_sna_ac_7.Perc7a_19 = research_19_sna_ac_7.Perc7a_19.astype(float)
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\412904590.py:3: SettingWithCopyWarning:
# ...

# %%
research_19_sna_ac_5 = pandas.concat([research_19_sna_ac_5[research_19_sna_ac_5.Perc5a_19 > sna_19_ac_avg_5 + 10], research_19_sna_ac_5[research_19_sna_ac_5.Perc5a_19 < sna_19_ac_avg_5 - 10]], axis=0)
research_19_sna_ac_5
# Out:
#        Level_Number Report_Number Table_Number Line_Number ccode  dcode  \
# 281728            1             0            1           1    30  66670
# 281740            1             0            1           1    30  66670
# 281752            1             0            1           1    30  66670
# 295450            1             0            1           1    30  66670
# 302236            1             0            1           1    30  66670
# 316150            1             0            1           1    30  66670
# 323026            1             0            1           1    30  66670
# 281734            1             0            1           1    30  66670
# 281758            1             0            1           1    30  66670
# 281764            1             0            1           1    30  66670
# 281770            1             0            1           1    30  66670
# 281776            1             0            1           1    30  66670
# ...

# %%
research_19_sna_ac_7 = pandas.concat([research_19_sna_ac_7[research_19_sna_ac_7.Perc7a_19 > sna_19_ac_avg_7 + 10], research_19_sna_ac_7[research_19_sna_ac_7.Perc7a_19 < sna_19_ac_avg_7 - 10]], axis=0)

# %%
research_19_sna_ac_9 = pandas.concat([research_19_sna_ac_9[research_19_sna_ac_9.Perc9a_19 > sna_19_ac_avg_9 + 10], research_19_sna_ac_9[research_19_sna_ac_9.Perc9a_19 < sna_19_ac_avg_9 - 10]], axis=0)

# %%
research_19_sna_bc = research_19.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")

# %%
# def highlight_19_sna_ac_5(cell):
#     if cell == "**" or cell == "0.0":
#         return 'color: orange'
#     elif float(cell) < (sna_19_ac_avg_5 - 10):
#         return 'color: red'
#     elif float(cell) > (sna_19_ac_avg_5 + 10):
#         return 'color: blue'
#     else:
#         return 'color: black'

# def highlight_19_sna_ac_7(cell):
#     if cell == "**" or cell == "0.0":
#         return 'color: orange'
#     elif float(cell) < (sna_19_ac_avg_7 - 10):
#         return 'color: red'
#     elif float(cell) > (sna_19_ac_avg_7 + 10):
#         return 'color: blue'
#     else:
#         return 'color: black'

# def highlight_19_sna_ac_9(cell):
#     if cell == "**" or cell == "0.0":
#         return 'color: orange'
#     elif float(cell) < (sna_19_ac_avg_9 - 10):
#         return 'color: red'
#     elif float(cell) > (sna_19_ac_avg_9 + 10):
#         return 'color: blue'
#     else:
#         return 'color: black'

# %%
research_19_sna_bc_5 = research_19_sna_bc.query("`Perc5a_19` != '0.0' and `Perc5a_19` != '**'")
research_19_sna_bc_7 = research_19_sna_bc.query("`Perc7a_19` != '0.0' and `Perc7a_19` != '**'")
research_19_sna_bc_9 = research_19_sna_bc.query("`Perc9a_19` != '0.0' and `Perc9a_19` != '**'")

research_19_sna_bc_5.Perc5a_19 = research_19_sna_bc_5.Perc5a_19.astype(float)
research_19_sna_bc_7.Perc7a_19 = research_19_sna_bc_7.Perc7a_19.astype(float)
research_19_sna_bc_9.Perc9a_19 = research_19_sna_bc_9.Perc9a_19.astype(float)

research_19_sna_bc_5 = pandas.concat([research_19_sna_bc_5[research_19_sna_bc_5.Perc5a_19 > sna_19_bc_avg_5 + 10], research_19_sna_bc_5[research_19_sna_bc_5.Perc5a_19 < sna_19_bc_avg_5 - 10]], axis=0)
research_19_sna_bc_7 = pandas.concat([research_19_sna_bc_7[research_19_sna_bc_7.Perc7a_19 > sna_19_bc_avg_7 + 10], research_19_sna_bc_7[research_19_sna_bc_7.Perc7a_19 < sna_19_bc_avg_7 - 10]], axis=0)
research_19_sna_bc_9 = pandas.concat([research_19_sna_bc_9[research_19_sna_bc_9.Perc9a_19 > sna_19_bc_avg_9 + 10], research_19_sna_bc_9[research_19_sna_bc_9.Perc9a_19 < sna_19_bc_avg_9 - 10]], axis=0)
# Out:
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\1328733442.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_19_sna_bc_5.Perc5a_19 = research_19_sna_bc_5.Perc5a_19.astype(float)
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\1328733442.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_19_sna_bc_7.Perc7a_19 = research_19_sna_bc_7.Perc7a_19.astype(float)
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\1328733442.py:7: SettingWithCopyWarning:
# ...

# %%
research_19_irv_ac = research_19.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")

# %%
research_19_irv_ac_5 = research_19_irv_ac.query("`Perc5a_19` != '0.0' and `Perc5a_19` != '**'")
research_19_irv_ac_7 = research_19_irv_ac.query("`Perc7a_19` != '0.0' and `Perc7a_19` != '**'")
research_19_irv_ac_9 = research_19_irv_ac.query("`Perc9a_19` != '0.0' and `Perc9a_19` != '**'")

research_19_irv_ac_5.Perc5a_19 = research_19_irv_ac_5.Perc5a_19.astype(float)
research_19_irv_ac_7.Perc7a_19 = research_19_irv_ac_7.Perc7a_19.astype(float)
research_19_irv_ac_9.Perc9a_19 = research_19_irv_ac_9.Perc9a_19.astype(float)

research_19_irv_ac_5 = pandas.concat([research_19_irv_ac_5[research_19_irv_ac_5.Perc5a_19 > irv_19_ac_avg_5 + 10], research_19_irv_ac_5[research_19_irv_ac_5.Perc5a_19 < irv_19_ac_avg_5 - 10]], axis=0)
research_19_irv_ac_7 = pandas.concat([research_19_irv_ac_7[research_19_irv_ac_7.Perc7a_19 > irv_19_ac_avg_7 + 10], research_19_irv_ac_7[research_19_irv_ac_7.Perc7a_19 < irv_19_ac_avg_7 - 10]], axis=0)
research_19_irv_ac_9 = pandas.concat([research_19_irv_ac_9[research_19_irv_ac_9.Perc9a_19 > irv_19_ac_avg_9 + 10], research_19_irv_ac_9[research_19_irv_ac_9.Perc9a_19 < irv_19_ac_avg_9 - 10]], axis=0)
# Out:
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\3367893206.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_19_irv_ac_5.Perc5a_19 = research_19_irv_ac_5.Perc5a_19.astype(float)
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\3367893206.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_19_irv_ac_7.Perc7a_19 = research_19_irv_ac_7.Perc7a_19.astype(float)
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\3367893206.py:7: SettingWithCopyWarning:
# ...

# %%
research_19_irv_bc = research_19.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")

# %%
research_19_irv_bc_5 = research_19_irv_bc.query("`Perc5a_19` != '0.0' and `Perc5a_19` != '**'")
research_19_irv_bc_7 = research_19_irv_bc.query("`Perc7a_19` != '0.0' and `Perc7a_19` != '**'")
research_19_irv_bc_9 = research_19_irv_bc.query("`Perc9a_19` != '0.0' and `Perc9a_19` != '**'")

research_19_irv_bc_5.Perc5a_19 = research_19_irv_bc_5.Perc5a_19.astype(float)
research_19_irv_bc_7.Perc7a_19 = research_19_irv_bc_7.Perc7a_19.astype(float)
research_19_irv_bc_9.Perc9a_19 = research_19_irv_bc_9.Perc9a_19.astype(float)

research_19_irv_bc_5 = pandas.concat([research_19_irv_bc_5[research_19_irv_bc_5.Perc5a_19 > irv_19_bc_avg_5 + 10], research_19_irv_bc_5[research_19_irv_bc_5.Perc5a_19 < irv_19_bc_avg_5 - 10]], axis=0)
research_19_irv_bc_7 = pandas.concat([research_19_irv_bc_7[research_19_irv_bc_7.Perc7a_19 > irv_19_bc_avg_7 + 10], research_19_irv_bc_7[research_19_irv_bc_7.Perc7a_19 < irv_19_bc_avg_7 - 10]], axis=0)
research_19_irv_bc_9 = pandas.concat([research_19_irv_bc_9[research_19_irv_bc_9.Perc9a_19 > irv_19_bc_avg_9 + 10], research_19_irv_bc_9[research_19_irv_bc_9.Perc9a_19 < irv_19_bc_avg_9 - 10]], axis=0)
# Out:
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\4274801738.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_19_irv_bc_5.Perc5a_19 = research_19_irv_bc_5.Perc5a_19.astype(float)
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\4274801738.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_19_irv_bc_7.Perc7a_19 = research_19_irv_bc_7.Perc7a_19.astype(float)
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\4274801738.py:7: SettingWithCopyWarning:
# ...

# %%
research_18 = pandas.read_csv("researchoutput18.txt",dtype=str,index_col=False)
research_18.rename(columns = {'CO': 'ccode', 'DIST':'dcode', 'SCHL':'scode', 'ChrtNum':'chrtnum', 'Perc5a':'Perc5a_18', 'Perc7a':'Perc7a_18', 'Perc9a':'Perc9a_18'}, inplace = True)
research_18_sna_ac = research_18.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")
research_18_sna_bc = research_18.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")
research_18_irv_ac = research_18.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")
research_18_irv_bc = research_18.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")
research_18_sna_ac['Line_Text'] = research_18_sna_ac['Line_Text'].str.strip()
research_18_sna_bc['Line_Text'] = research_18_sna_bc['Line_Text'].str.strip()
research_18_irv_ac['Line_Text'] = research_18_irv_ac['Line_Text'].str.strip()
research_18_irv_bc['Line_Text'] = research_18_irv_bc['Line_Text'].str.strip()
research_18_sna_ac['Perc5a_18'] = research_18_sna_ac['Perc5a_18'].str.strip()
research_18_sna_bc['Perc5a_18'] = research_18_sna_bc['Perc5a_18'].str.strip()
research_18_irv_ac['Perc5a_18'] = research_18_irv_ac['Perc5a_18'].str.strip()
research_18_irv_bc['Perc5a_18'] = research_18_irv_bc['Perc5a_18'].str.strip()
research_18_sna_ac['Perc7a_18'] = research_18_sna_ac['Perc7a_18'].str.strip()
research_18_sna_bc['Perc7a_18'] = research_18_sna_bc['Perc7a_18'].str.strip()
research_18_irv_ac['Perc7a_18'] = research_18_irv_ac['Perc7a_18'].str.strip()
research_18_irv_bc['Perc7a_18'] = research_18_irv_bc['Perc7a_18'].str.strip()
research_18_sna_ac['Perc9a_18'] = research_18_sna_ac['Perc9a_18'].str.strip()
research_18_sna_bc['Perc9a_18'] = research_18_sna_bc['Perc9a_18'].str.strip()
research_18_irv_ac['Perc9a_18'] = research_18_irv_ac['Perc9a_18'].str.strip()
research_18_irv_bc['Perc9a_18'] = research_18_irv_bc['Perc9a_18'].str.strip()

research_18_sna_ac_5 = research_18_sna_ac.query("`Perc5a_18` != '0.0' and `Perc5a_18` != '**'")
research_18_sna_ac_7 = research_18_sna_ac.query("`Perc7a_18` != '0.0' and `Perc7a_18` != '**'")
research_18_sna_ac_9 = research_18_sna_ac.query("`Perc9a_18` != '0.0' and `Perc9a_18` != '**'")
research_18_sna_ac_5.Perc5a_18 = research_18_sna_ac_5.Perc5a_18.astype(float)
research_18_sna_ac_7.Perc7a_18 = research_18_sna_ac_7.Perc7a_18.astype(float)
research_18_sna_ac_9.Perc9a_18 = research_18_sna_ac_9.Perc9a_18.astype(float)
research_18_sna_ac_5 = pandas.concat([research_18_sna_ac_5[research_18_sna_ac_5.Perc5a_18 > sna_18_ac_avg_5 + 10], research_18_sna_ac_5[research_18_sna_ac_5.Perc5a_18 < sna_18_ac_avg_5 - 10]], axis=0)
research_18_sna_ac_7 = pandas.concat([research_18_sna_ac_7[research_18_sna_ac_7.Perc7a_18 > sna_18_ac_avg_7 + 10], research_18_sna_ac_7[research_18_sna_ac_7.Perc7a_18 < sna_18_ac_avg_7 - 10]], axis=0)
research_18_sna_ac_9 = pandas.concat([research_18_sna_ac_9[research_18_sna_ac_9.Perc9a_18 > sna_18_ac_avg_9 + 10], research_18_sna_ac_9[research_18_sna_ac_9.Perc9a_18 < sna_18_ac_avg_9 - 10]], axis=0)

research_18_sna_bc_5 = research_18_sna_bc.query("`Perc5a_18` != '0.0' and `Perc5a_18` != '**'")
research_18_sna_bc_7 = research_18_sna_bc.query("`Perc7a_18` != '0.0' and `Perc7a_18` != '**'")
research_18_sna_bc_9 = research_18_sna_bc.query("`Perc9a_18` != '0.0' and `Perc9a_18` != '**'")
research_18_sna_bc_5.Perc5a_18 = research_18_sna_bc_5.Perc5a_18.astype(float)
research_18_sna_bc_7.Perc7a_18 = research_18_sna_bc_7.Perc7a_18.astype(float)
research_18_sna_bc_9.Perc9a_18 = research_18_sna_bc_9.Perc9a_18.astype(float)
research_18_sna_bc_5 = pandas.concat([research_18_sna_bc_5[research_18_sna_bc_5.Perc5a_18 > sna_18_bc_avg_5 + 10], research_18_sna_bc_5[research_18_sna_bc_5.Perc5a_18 < sna_18_bc_avg_5 - 10]], axis=0)
research_18_sna_bc_7 = pandas.concat([research_18_sna_bc_7[research_18_sna_bc_7.Perc7a_18 > sna_18_bc_avg_7 + 10], research_18_sna_bc_7[research_18_sna_bc_7.Perc7a_18 < sna_18_bc_avg_7 - 10]], axis=0)
research_18_sna_bc_9 = pandas.concat([research_18_sna_bc_9[research_18_sna_bc_9.Perc9a_18 > sna_18_bc_avg_9 + 10], research_18_sna_bc_9[research_18_sna_bc_9.Perc9a_18 < sna_18_bc_avg_9 - 10]], axis=0)

research_18_irv_ac_5 = research_18_irv_ac.query("`Perc5a_18` != '0.0' and `Perc5a_18` != '**'")
research_18_irv_ac_7 = research_18_irv_ac.query("`Perc7a_18` != '0.0' and `Perc7a_18` != '**'")
research_18_irv_ac_9 = research_18_irv_ac.query("`Perc9a_18` != '0.0' and `Perc9a_18` != '**'")
research_18_irv_ac_5.Perc5a_18 = research_18_irv_ac_5.Perc5a_18.astype(float)
research_18_irv_ac_7.Perc7a_18 = research_18_irv_ac_7.Perc7a_18.astype(float)
research_18_irv_ac_9.Perc9a_18 = research_18_irv_ac_9.Perc9a_18.astype(float)
research_18_irv_ac_5 = pandas.concat([research_18_irv_ac_5[research_18_irv_ac_5.Perc5a_18 > irv_18_ac_avg_5 + 10], research_18_irv_ac_5[research_18_irv_ac_5.Perc5a_18 < irv_18_ac_avg_5 - 10]], axis=0)
research_18_irv_ac_7 = pandas.concat([research_18_irv_ac_7[research_18_irv_ac_7.Perc7a_18 > irv_18_ac_avg_7 + 10], research_18_irv_ac_7[research_18_irv_ac_7.Perc7a_18 < irv_18_ac_avg_7 - 10]], axis=0)
research_18_irv_ac_9 = pandas.concat([research_18_irv_ac_9[research_18_irv_ac_9.Perc9a_18 > irv_18_ac_avg_9 + 10], research_18_irv_ac_9[research_18_irv_ac_9.Perc9a_18 < irv_18_ac_avg_9 - 10]], axis=0)

research_18_irv_bc_5 = research_18_irv_bc.query("`Perc5a_18` != '0.0' and `Perc5a_18` != '**'")
research_18_irv_bc_7 = research_18_irv_bc.query("`Perc7a_18` != '0.0' and `Perc7a_18` != '**'")
research_18_irv_bc_9 = research_18_irv_bc.query("`Perc9a_18` != '0.0' and `Perc9a_18` != '**'")
research_18_irv_bc_5.Perc5a_18 = research_18_irv_bc_5.Perc5a_18.astype(float)
research_18_irv_bc_7.Perc7a_18 = research_18_irv_bc_7.Perc7a_18.astype(float)
research_18_irv_bc_9.Perc9a_18 = research_18_irv_bc_9.Perc9a_18.astype(float)
research_18_irv_bc_5 = pandas.concat([research_18_irv_bc_5[research_18_irv_bc_5.Perc5a_18 > irv_18_bc_avg_5 + 10], research_18_irv_bc_5[research_18_irv_bc_5.Perc5a_18 < irv_18_bc_avg_5 - 10]], axis=0)
research_18_irv_bc_7 = pandas.concat([research_18_irv_bc_7[research_18_irv_bc_7.Perc7a_18 > irv_18_bc_avg_7 + 10], research_18_irv_bc_7[research_18_irv_bc_7.Perc7a_18 < irv_18_bc_avg_7 - 10]], axis=0)
research_18_irv_bc_9 = pandas.concat([research_18_irv_bc_9[research_18_irv_bc_9.Perc9a_18 > irv_18_bc_avg_9 + 10], research_18_irv_bc_9[research_18_irv_bc_9.Perc9a_18 < irv_18_bc_avg_9 - 10]], axis=0)
# Out:
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\1525764468.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_18_sna_ac['Line_Text'] = research_18_sna_ac['Line_Text'].str.strip()
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\1525764468.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_18_sna_bc['Line_Text'] = research_18_sna_bc['Line_Text'].str.strip()
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\1525764468.py:9: SettingWithCopyWarning:
# ...

# %%
research_17 = pandas.read_csv("researchoutput17.txt",dtype=str,index_col=False)
research_17.rename(columns = {'CO': 'ccode', 'DIST':'dcode', 'SCHL':'scode', 'ChrtNum':'chrtnum', 'Perc5a':'Perc5a_17', 'Perc7a':'Perc7a_17', 'Perc9a':'Perc9a_17'}, inplace = True)
research_17_sna_ac = research_17.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")
research_17_sna_bc = research_17.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")
research_17_irv_ac = research_17.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")
research_17_irv_bc = research_17.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")
research_17_sna_ac['Line_Text'] = research_17_sna_ac['Line_Text'].str.strip()
research_17_sna_bc['Line_Text'] = research_17_sna_bc['Line_Text'].str.strip()
research_17_irv_ac['Line_Text'] = research_17_irv_ac['Line_Text'].str.strip()
research_17_irv_bc['Line_Text'] = research_17_irv_bc['Line_Text'].str.strip()
research_17_sna_ac['Perc5a_17'] = research_17_sna_ac['Perc5a_17'].str.strip()
research_17_sna_bc['Perc5a_17'] = research_17_sna_bc['Perc5a_17'].str.strip()
research_17_irv_ac['Perc5a_17'] = research_17_irv_ac['Perc5a_17'].str.strip()
research_17_irv_bc['Perc5a_17'] = research_17_irv_bc['Perc5a_17'].str.strip()
research_17_sna_ac['Perc7a_17'] = research_17_sna_ac['Perc7a_17'].str.strip()
research_17_sna_bc['Perc7a_17'] = research_17_sna_bc['Perc7a_17'].str.strip()
research_17_irv_ac['Perc7a_17'] = research_17_irv_ac['Perc7a_17'].str.strip()
research_17_irv_bc['Perc7a_17'] = research_17_irv_bc['Perc7a_17'].str.strip()
research_17_sna_ac['Perc9a_17'] = research_17_sna_ac['Perc9a_17'].str.strip()
research_17_sna_bc['Perc9a_17'] = research_17_sna_bc['Perc9a_17'].str.strip()
research_17_irv_ac['Perc9a_17'] = research_17_irv_ac['Perc9a_17'].str.strip()
research_17_irv_bc['Perc9a_17'] = research_17_irv_bc['Perc9a_17'].str.strip()

research_17_sna_ac_5 = research_17_sna_ac.query("`Perc5a_17` != '0.0' and `Perc5a_17` != '**'")
research_17_sna_ac_7 = research_17_sna_ac.query("`Perc7a_17` != '0.0' and `Perc7a_17` != '**'")
research_17_sna_ac_9 = research_17_sna_ac.query("`Perc9a_17` != '0.0' and `Perc9a_17` != '**'")
research_17_sna_ac_5.Perc5a_17 = research_17_sna_ac_5.Perc5a_17.astype(float)
research_17_sna_ac_7.Perc7a_17 = research_17_sna_ac_7.Perc7a_17.astype(float)
research_17_sna_ac_9.Perc9a_17 = research_17_sna_ac_9.Perc9a_17.astype(float)
research_17_sna_ac_5 = pandas.concat([research_17_sna_ac_5[research_17_sna_ac_5.Perc5a_17 > sna_17_ac_avg_5 + 10], research_17_sna_ac_5[research_17_sna_ac_5.Perc5a_17 < sna_17_ac_avg_5 - 10]], axis=0)
research_17_sna_ac_7 = pandas.concat([research_17_sna_ac_7[research_17_sna_ac_7.Perc7a_17 > sna_17_ac_avg_7 + 10], research_17_sna_ac_7[research_17_sna_ac_7.Perc7a_17 < sna_17_ac_avg_7 - 10]], axis=0)
research_17_sna_ac_9 = pandas.concat([research_17_sna_ac_9[research_17_sna_ac_9.Perc9a_17 > sna_17_ac_avg_9 + 10], research_17_sna_ac_9[research_17_sna_ac_9.Perc9a_17 < sna_17_ac_avg_9 - 10]], axis=0)

research_17_sna_bc_5 = research_17_sna_bc.query("`Perc5a_17` != '0.0' and `Perc5a_17` != '**'")
research_17_sna_bc_7 = research_17_sna_bc.query("`Perc7a_17` != '0.0' and `Perc7a_17` != '**'")
research_17_sna_bc_9 = research_17_sna_bc.query("`Perc9a_17` != '0.0' and `Perc9a_17` != '**'")
research_17_sna_bc_5.Perc5a_17 = research_17_sna_bc_5.Perc5a_17.astype(float)
research_17_sna_bc_7.Perc7a_17 = research_17_sna_bc_7.Perc7a_17.astype(float)
research_17_sna_bc_9.Perc9a_17 = research_17_sna_bc_9.Perc9a_17.astype(float)
research_17_sna_bc_5 = pandas.concat([research_17_sna_bc_5[research_17_sna_bc_5.Perc5a_17 > sna_17_bc_avg_5 + 10], research_17_sna_bc_5[research_17_sna_bc_5.Perc5a_17 < sna_17_bc_avg_5 - 10]], axis=0)
research_17_sna_bc_7 = pandas.concat([research_17_sna_bc_7[research_17_sna_bc_7.Perc7a_17 > sna_17_bc_avg_7 + 10], research_17_sna_bc_7[research_17_sna_bc_7.Perc7a_17 < sna_17_bc_avg_7 - 10]], axis=0)
research_17_sna_bc_9 = pandas.concat([research_17_sna_bc_9[research_17_sna_bc_9.Perc9a_17 > sna_17_bc_avg_9 + 10], research_17_sna_bc_9[research_17_sna_bc_9.Perc9a_17 < sna_17_bc_avg_9 - 10]], axis=0)

research_17_irv_ac_5 = research_17_irv_ac.query("`Perc5a_17` != '0.0' and `Perc5a_17` != '**'")
research_17_irv_ac_7 = research_17_irv_ac.query("`Perc7a_17` != '0.0' and `Perc7a_17` != '**'")
research_17_irv_ac_9 = research_17_irv_ac.query("`Perc9a_17` != '0.0' and `Perc9a_17` != '**'")
research_17_irv_ac_5.Perc5a_17 = research_17_irv_ac_5.Perc5a_17.astype(float)
research_17_irv_ac_7.Perc7a_17 = research_17_irv_ac_7.Perc7a_17.astype(float)
research_17_irv_ac_9.Perc9a_17 = research_17_irv_ac_9.Perc9a_17.astype(float)
research_17_irv_ac_5 = pandas.concat([research_17_irv_ac_5[research_17_irv_ac_5.Perc5a_17 > irv_17_ac_avg_5 + 10], research_17_irv_ac_5[research_17_irv_ac_5.Perc5a_17 < irv_17_ac_avg_5 - 10]], axis=0)
research_17_irv_ac_7 = pandas.concat([research_17_irv_ac_7[research_17_irv_ac_7.Perc7a_17 > irv_17_ac_avg_7 + 10], research_17_irv_ac_7[research_17_irv_ac_7.Perc7a_17 < irv_17_ac_avg_7 - 10]], axis=0)
research_17_irv_ac_9 = pandas.concat([research_17_irv_ac_9[research_17_irv_ac_9.Perc9a_17 > irv_17_ac_avg_9 + 10], research_17_irv_ac_9[research_17_irv_ac_9.Perc9a_17 < irv_17_ac_avg_9 - 10]], axis=0)

research_17_irv_bc_5 = research_17_irv_bc.query("`Perc5a_17` != '0.0' and `Perc5a_17` != '**'")
research_17_irv_bc_7 = research_17_irv_bc.query("`Perc7a_17` != '0.0' and `Perc7a_17` != '**'")
research_17_irv_bc_9 = research_17_irv_bc.query("`Perc9a_17` != '0.0' and `Perc9a_17` != '**'")
research_17_irv_bc_5.Perc5a_17 = research_17_irv_bc_5.Perc5a_17.astype(float)
research_17_irv_bc_7.Perc7a_17 = research_17_irv_bc_7.Perc7a_17.astype(float)
research_17_irv_bc_9.Perc9a_17 = research_17_irv_bc_9.Perc9a_17.astype(float)
research_17_irv_bc_5 = pandas.concat([research_17_irv_bc_5[research_17_irv_bc_5.Perc5a_17 > irv_17_bc_avg_5 + 10], research_17_irv_bc_5[research_17_irv_bc_5.Perc5a_17 < irv_17_bc_avg_5 - 10]], axis=0)
research_17_irv_bc_7 = pandas.concat([research_17_irv_bc_7[research_17_irv_bc_7.Perc7a_17 > irv_17_bc_avg_7 + 10], research_17_irv_bc_7[research_17_irv_bc_7.Perc7a_17 < irv_17_bc_avg_7 - 10]], axis=0)
research_17_irv_bc_9 = pandas.concat([research_17_irv_bc_9[research_17_irv_bc_9.Perc9a_17 > irv_17_bc_avg_9 + 10], research_17_irv_bc_9[research_17_irv_bc_9.Perc9a_17 < irv_17_bc_avg_9 - 10]], axis=0)
# Out:
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\4025848710.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_17_sna_ac['Line_Text'] = research_17_sna_ac['Line_Text'].str.strip()
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\4025848710.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_17_sna_bc['Line_Text'] = research_17_sna_bc['Line_Text'].str.strip()
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\4025848710.py:9: SettingWithCopyWarning:
# ...

# %%
research_16 = pandas.read_csv("researchoutput16.txt",dtype=str,index_col=False)
research_16.rename(columns = {'CO': 'ccode', 'DIST':'dcode', 'SCHL':'scode', 'ChrtNum':'chrtnum', 'Perc5a':'Perc5a_16', 'Perc7a':'Perc7a_16', 'Perc9a':'Perc9a_16'}, inplace = True)
research_16_sna_ac = research_16.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")
research_16_sna_bc = research_16.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")
research_16_irv_ac = research_16.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")
research_16_irv_bc = research_16.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")
research_16_sna_ac['Line_Text'] = research_16_sna_ac['Line_Text'].str.strip()
research_16_sna_bc['Line_Text'] = research_16_sna_bc['Line_Text'].str.strip()
research_16_irv_ac['Line_Text'] = research_16_irv_ac['Line_Text'].str.strip()
research_16_irv_bc['Line_Text'] = research_16_irv_bc['Line_Text'].str.strip()
research_16_sna_ac['Perc5a_16'] = research_16_sna_ac['Perc5a_16'].str.strip()
research_16_sna_bc['Perc5a_16'] = research_16_sna_bc['Perc5a_16'].str.strip()
research_16_irv_ac['Perc5a_16'] = research_16_irv_ac['Perc5a_16'].str.strip()
research_16_irv_bc['Perc5a_16'] = research_16_irv_bc['Perc5a_16'].str.strip()
research_16_sna_ac['Perc7a_16'] = research_16_sna_ac['Perc7a_16'].str.strip()
research_16_sna_bc['Perc7a_16'] = research_16_sna_bc['Perc7a_16'].str.strip()
research_16_irv_ac['Perc7a_16'] = research_16_irv_ac['Perc7a_16'].str.strip()
research_16_irv_bc['Perc7a_16'] = research_16_irv_bc['Perc7a_16'].str.strip()
research_16_sna_ac['Perc9a_16'] = research_16_sna_ac['Perc9a_16'].str.strip()
research_16_sna_bc['Perc9a_16'] = research_16_sna_bc['Perc9a_16'].str.strip()
research_16_irv_ac['Perc9a_16'] = research_16_irv_ac['Perc9a_16'].str.strip()
research_16_irv_bc['Perc9a_16'] = research_16_irv_bc['Perc9a_16'].str.strip()

research_16_sna_ac_5 = research_16_sna_ac.query("`Perc5a_16` != '0.0' and `Perc5a_16` != '**'")
research_16_sna_ac_7 = research_16_sna_ac.query("`Perc7a_16` != '0.0' and `Perc7a_16` != '**'")
research_16_sna_ac_9 = research_16_sna_ac.query("`Perc9a_16` != '0.0' and `Perc9a_16` != '**'")
research_16_sna_ac_5.Perc5a_16 = research_16_sna_ac_5.Perc5a_16.astype(float)
research_16_sna_ac_7.Perc7a_16 = research_16_sna_ac_7.Perc7a_16.astype(float)
research_16_sna_ac_9.Perc9a_16 = research_16_sna_ac_9.Perc9a_16.astype(float)
research_16_sna_ac_5 = pandas.concat([research_16_sna_ac_5[research_16_sna_ac_5.Perc5a_16 > sna_16_ac_avg_5 + 10], research_16_sna_ac_5[research_16_sna_ac_5.Perc5a_16 < sna_16_ac_avg_5 - 10]], axis=0)
research_16_sna_ac_7 = pandas.concat([research_16_sna_ac_7[research_16_sna_ac_7.Perc7a_16 > sna_16_ac_avg_7 + 10], research_16_sna_ac_7[research_16_sna_ac_7.Perc7a_16 < sna_16_ac_avg_7 - 10]], axis=0)
research_16_sna_ac_9 = pandas.concat([research_16_sna_ac_9[research_16_sna_ac_9.Perc9a_16 > sna_16_ac_avg_9 + 10], research_16_sna_ac_9[research_16_sna_ac_9.Perc9a_16 < sna_16_ac_avg_9 - 10]], axis=0)

research_16_sna_bc_5 = research_16_sna_bc.query("`Perc5a_16` != '0.0' and `Perc5a_16` != '**'")
research_16_sna_bc_7 = research_16_sna_bc.query("`Perc7a_16` != '0.0' and `Perc7a_16` != '**'")
research_16_sna_bc_9 = research_16_sna_bc.query("`Perc9a_16` != '0.0' and `Perc9a_16` != '**'")
research_16_sna_bc_5.Perc5a_16 = research_16_sna_bc_5.Perc5a_16.astype(float)
research_16_sna_bc_7.Perc7a_16 = research_16_sna_bc_7.Perc7a_16.astype(float)
research_16_sna_bc_9.Perc9a_16 = research_16_sna_bc_9.Perc9a_16.astype(float)
research_16_sna_bc_5 = pandas.concat([research_16_sna_bc_5[research_16_sna_bc_5.Perc5a_16 > sna_16_bc_avg_5 + 10], research_16_sna_bc_5[research_16_sna_bc_5.Perc5a_16 < sna_16_bc_avg_5 - 10]], axis=0)
research_16_sna_bc_7 = pandas.concat([research_16_sna_bc_7[research_16_sna_bc_7.Perc7a_16 > sna_16_bc_avg_7 + 10], research_16_sna_bc_7[research_16_sna_bc_7.Perc7a_16 < sna_16_bc_avg_7 - 10]], axis=0)
research_16_sna_bc_9 = pandas.concat([research_16_sna_bc_9[research_16_sna_bc_9.Perc9a_16 > sna_16_bc_avg_9 + 10], research_16_sna_bc_9[research_16_sna_bc_9.Perc9a_16 < sna_16_bc_avg_9 - 10]], axis=0)

research_16_irv_ac_5 = research_16_irv_ac.query("`Perc5a_16` != '0.0' and `Perc5a_16` != '**'")
research_16_irv_ac_7 = research_16_irv_ac.query("`Perc7a_16` != '0.0' and `Perc7a_16` != '**'")
research_16_irv_ac_9 = research_16_irv_ac.query("`Perc9a_16` != '0.0' and `Perc9a_16` != '**'")
research_16_irv_ac_5.Perc5a_16 = research_16_irv_ac_5.Perc5a_16.astype(float)
research_16_irv_ac_7.Perc7a_16 = research_16_irv_ac_7.Perc7a_16.astype(float)
research_16_irv_ac_9.Perc9a_16 = research_16_irv_ac_9.Perc9a_16.astype(float)
research_16_irv_ac_5 = pandas.concat([research_16_irv_ac_5[research_16_irv_ac_5.Perc5a_16 > irv_16_ac_avg_5 + 10], research_16_irv_ac_5[research_16_irv_ac_5.Perc5a_16 < irv_16_ac_avg_5 - 10]], axis=0)
research_16_irv_ac_7 = pandas.concat([research_16_irv_ac_7[research_16_irv_ac_7.Perc7a_16 > irv_16_ac_avg_7 + 10], research_16_irv_ac_7[research_16_irv_ac_7.Perc7a_16 < irv_16_ac_avg_7 - 10]], axis=0)
research_16_irv_ac_9 = pandas.concat([research_16_irv_ac_9[research_16_irv_ac_9.Perc9a_16 > irv_16_ac_avg_9 + 10], research_16_irv_ac_9[research_16_irv_ac_9.Perc9a_16 < irv_16_ac_avg_9 - 10]], axis=0)

research_16_irv_bc_5 = research_16_irv_bc.query("`Perc5a_16` != '0.0' and `Perc5a_16` != '**'")
research_16_irv_bc_7 = research_16_irv_bc.query("`Perc7a_16` != '0.0' and `Perc7a_16` != '**'")
research_16_irv_bc_9 = research_16_irv_bc.query("`Perc9a_16` != '0.0' and `Perc9a_16` != '**'")
research_16_irv_bc_5.Perc5a_16 = research_16_irv_bc_5.Perc5a_16.astype(float)
research_16_irv_bc_7.Perc7a_16 = research_16_irv_bc_7.Perc7a_16.astype(float)
research_16_irv_bc_9.Perc9a_16 = research_16_irv_bc_9.Perc9a_16.astype(float)
research_16_irv_bc_5 = pandas.concat([research_16_irv_bc_5[research_16_irv_bc_5.Perc5a_16 > irv_16_bc_avg_5 + 10], research_16_irv_bc_5[research_16_irv_bc_5.Perc5a_16 < irv_16_bc_avg_5 - 10]], axis=0)
research_16_irv_bc_7 = pandas.concat([research_16_irv_bc_7[research_16_irv_bc_7.Perc7a_16 > irv_16_bc_avg_7 + 10], research_16_irv_bc_7[research_16_irv_bc_7.Perc7a_16 < irv_16_bc_avg_7 - 10]], axis=0)
research_16_irv_bc_9 = pandas.concat([research_16_irv_bc_9[research_16_irv_bc_9.Perc9a_16 > irv_16_bc_avg_9 + 10], research_16_irv_bc_9[research_16_irv_bc_9.Perc9a_16 < irv_16_bc_avg_9 - 10]], axis=0)
# Out:
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\2083590496.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_16_sna_ac['Line_Text'] = research_16_sna_ac['Line_Text'].str.strip()
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\2083590496.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_16_sna_bc['Line_Text'] = research_16_sna_bc['Line_Text'].str.strip()
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\2083590496.py:9: SettingWithCopyWarning:
# ...

# %%
research_15 = pandas.read_csv("researchoutput15.txt",dtype=str,index_col=False)
research_15.rename(columns = {'CO': 'ccode', 'DIST':'dcode', 'SCHL':'scode', 'ChrtNum':'chrtnum', 'Perc5a':'Perc5a_15', 'Perc7a':'Perc7a_15', 'Perc9a':'Perc9a_15'}, inplace = True)
research_15_sna_ac = research_15.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")
research_15_sna_bc = research_15.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")
research_15_irv_ac = research_15.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")
research_15_irv_bc = research_15.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")
research_15_sna_ac['Line_Text'] = research_15_sna_ac['Line_Text'].str.strip()
research_15_sna_bc['Line_Text'] = research_15_sna_bc['Line_Text'].str.strip()
research_15_irv_ac['Line_Text'] = research_15_irv_ac['Line_Text'].str.strip()
research_15_irv_bc['Line_Text'] = research_15_irv_bc['Line_Text'].str.strip()
research_15_sna_ac['Perc5a_15'] = research_15_sna_ac['Perc5a_15'].str.strip()
research_15_sna_bc['Perc5a_15'] = research_15_sna_bc['Perc5a_15'].str.strip()
research_15_irv_ac['Perc5a_15'] = research_15_irv_ac['Perc5a_15'].str.strip()
research_15_irv_bc['Perc5a_15'] = research_15_irv_bc['Perc5a_15'].str.strip()
research_15_sna_ac['Perc7a_15'] = research_15_sna_ac['Perc7a_15'].str.strip()
research_15_sna_bc['Perc7a_15'] = research_15_sna_bc['Perc7a_15'].str.strip()
research_15_irv_ac['Perc7a_15'] = research_15_irv_ac['Perc7a_15'].str.strip()
research_15_irv_bc['Perc7a_15'] = research_15_irv_bc['Perc7a_15'].str.strip()
research_15_sna_ac['Perc9a_15'] = research_15_sna_ac['Perc9a_15'].str.strip()
research_15_sna_bc['Perc9a_15'] = research_15_sna_bc['Perc9a_15'].str.strip()
research_15_irv_ac['Perc9a_15'] = research_15_irv_ac['Perc9a_15'].str.strip()
research_15_irv_bc['Perc9a_15'] = research_15_irv_bc['Perc9a_15'].str.strip()

research_15_sna_ac_5 = research_15_sna_ac.query("`Perc5a_15` != '0.0' and `Perc5a_15` != '**'")
research_15_sna_ac_7 = research_15_sna_ac.query("`Perc7a_15` != '0.0' and `Perc7a_15` != '**'")
research_15_sna_ac_9 = research_15_sna_ac.query("`Perc9a_15` != '0.0' and `Perc9a_15` != '**'")
research_15_sna_ac_5.Perc5a_15 = research_15_sna_ac_5.Perc5a_15.astype(float)
research_15_sna_ac_7.Perc7a_15 = research_15_sna_ac_7.Perc7a_15.astype(float)
research_15_sna_ac_9.Perc9a_15 = research_15_sna_ac_9.Perc9a_15.astype(float)
research_15_sna_ac_5 = pandas.concat([research_15_sna_ac_5[research_15_sna_ac_5.Perc5a_15 > sna_15_ac_avg_5 + 10], research_15_sna_ac_5[research_15_sna_ac_5.Perc5a_15 < sna_15_ac_avg_5 - 10]], axis=0)
research_15_sna_ac_7 = pandas.concat([research_15_sna_ac_7[research_15_sna_ac_7.Perc7a_15 > sna_15_ac_avg_7 + 10], research_15_sna_ac_7[research_15_sna_ac_7.Perc7a_15 < sna_15_ac_avg_7 - 10]], axis=0)
research_15_sna_ac_9 = pandas.concat([research_15_sna_ac_9[research_15_sna_ac_9.Perc9a_15 > sna_15_ac_avg_9 + 10], research_15_sna_ac_9[research_15_sna_ac_9.Perc9a_15 < sna_15_ac_avg_9 - 10]], axis=0)

research_15_sna_bc_5 = research_15_sna_bc.query("`Perc5a_15` != '0.0' and `Perc5a_15` != '**'")
research_15_sna_bc_7 = research_15_sna_bc.query("`Perc7a_15` != '0.0' and `Perc7a_15` != '**'")
research_15_sna_bc_9 = research_15_sna_bc.query("`Perc9a_15` != '0.0' and `Perc9a_15` != '**'")
research_15_sna_bc_5.Perc5a_15 = research_15_sna_bc_5.Perc5a_15.astype(float)
research_15_sna_bc_7.Perc7a_15 = research_15_sna_bc_7.Perc7a_15.astype(float)
research_15_sna_bc_9.Perc9a_15 = research_15_sna_bc_9.Perc9a_15.astype(float)
research_15_sna_bc_5 = pandas.concat([research_15_sna_bc_5[research_15_sna_bc_5.Perc5a_15 > sna_15_bc_avg_5 + 10], research_15_sna_bc_5[research_15_sna_bc_5.Perc5a_15 < sna_15_bc_avg_5 - 10]], axis=0)
research_15_sna_bc_7 = pandas.concat([research_15_sna_bc_7[research_15_sna_bc_7.Perc7a_15 > sna_15_bc_avg_7 + 10], research_15_sna_bc_7[research_15_sna_bc_7.Perc7a_15 < sna_15_bc_avg_7 - 10]], axis=0)
research_15_sna_bc_9 = pandas.concat([research_15_sna_bc_9[research_15_sna_bc_9.Perc9a_15 > sna_15_bc_avg_9 + 10], research_15_sna_bc_9[research_15_sna_bc_9.Perc9a_15 < sna_15_bc_avg_9 - 10]], axis=0)

research_15_irv_ac_5 = research_15_irv_ac.query("`Perc5a_15` != '0.0' and `Perc5a_15` != '**'")
research_15_irv_ac_7 = research_15_irv_ac.query("`Perc7a_15` != '0.0' and `Perc7a_15` != '**'")
research_15_irv_ac_9 = research_15_irv_ac.query("`Perc9a_15` != '0.0' and `Perc9a_15` != '**'")
research_15_irv_ac_5.Perc5a_15 = research_15_irv_ac_5.Perc5a_15.astype(float)
research_15_irv_ac_7.Perc7a_15 = research_15_irv_ac_7.Perc7a_15.astype(float)
research_15_irv_ac_9.Perc9a_15 = research_15_irv_ac_9.Perc9a_15.astype(float)
research_15_irv_ac_5 = pandas.concat([research_15_irv_ac_5[research_15_irv_ac_5.Perc5a_15 > irv_15_ac_avg_5 + 10], research_15_irv_ac_5[research_15_irv_ac_5.Perc5a_15 < irv_15_ac_avg_5 - 10]], axis=0)
research_15_irv_ac_7 = pandas.concat([research_15_irv_ac_7[research_15_irv_ac_7.Perc7a_15 > irv_15_ac_avg_7 + 10], research_15_irv_ac_7[research_15_irv_ac_7.Perc7a_15 < irv_15_ac_avg_7 - 10]], axis=0)
research_15_irv_ac_9 = pandas.concat([research_15_irv_ac_9[research_15_irv_ac_9.Perc9a_15 > irv_15_ac_avg_9 + 10], research_15_irv_ac_9[research_15_irv_ac_9.Perc9a_15 < irv_15_ac_avg_9 - 10]], axis=0)

research_15_irv_bc_5 = research_15_irv_bc.query("`Perc5a_15` != '0.0' and `Perc5a_15` != '**'")
research_15_irv_bc_7 = research_15_irv_bc.query("`Perc7a_15` != '0.0' and `Perc7a_15` != '**'")
research_15_irv_bc_9 = research_15_irv_bc.query("`Perc9a_15` != '0.0' and `Perc9a_15` != '**'")
research_15_irv_bc_5.Perc5a_15 = research_15_irv_bc_5.Perc5a_15.astype(float)
research_15_irv_bc_7.Perc7a_15 = research_15_irv_bc_7.Perc7a_15.astype(float)
research_15_irv_bc_9.Perc9a_15 = research_15_irv_bc_9.Perc9a_15.astype(float)
research_15_irv_bc_5 = pandas.concat([research_15_irv_bc_5[research_15_irv_bc_5.Perc5a_15 > irv_15_bc_avg_5 + 10], research_15_irv_bc_5[research_15_irv_bc_5.Perc5a_15 < irv_15_bc_avg_5 - 10]], axis=0)
research_15_irv_bc_7 = pandas.concat([research_15_irv_bc_7[research_15_irv_bc_7.Perc7a_15 > irv_15_bc_avg_7 + 10], research_15_irv_bc_7[research_15_irv_bc_7.Perc7a_15 < irv_15_bc_avg_7 - 10]], axis=0)
research_15_irv_bc_9 = pandas.concat([research_15_irv_bc_9[research_15_irv_bc_9.Perc9a_15 > irv_15_bc_avg_9 + 10], research_15_irv_bc_9[research_15_irv_bc_9.Perc9a_15 < irv_15_bc_avg_9 - 10]], axis=0)
# Out:
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\2443156320.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_15_sna_ac['Line_Text'] = research_15_sna_ac['Line_Text'].str.strip()
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\2443156320.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_15_sna_bc['Line_Text'] = research_15_sna_bc['Line_Text'].str.strip()
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\2443156320.py:9: SettingWithCopyWarning:
# ...

# %%
research_14 = pandas.read_csv("researchoutput14.txt",dtype=str,index_col=False)
research_14.rename(columns = {'CO': 'ccode', 'DIST':'dcode', 'SCHL':'scode', 'ChrtNum':'chrtnum', 'Perc5a':'Perc5a_14', 'Perc7a':'Perc7a_14', 'Perc9a':'Perc9a_14'}, inplace = True)
research_14_sna_ac = research_14.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")
research_14_sna_bc = research_14.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")
research_14_irv_ac = research_14.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")
research_14_irv_bc = research_14.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")
research_14_sna_ac['Line_Text'] = research_14_sna_ac['Line_Text'].str.strip()
research_14_sna_bc['Line_Text'] = research_14_sna_bc['Line_Text'].str.strip()
research_14_irv_ac['Line_Text'] = research_14_irv_ac['Line_Text'].str.strip()
research_14_irv_bc['Line_Text'] = research_14_irv_bc['Line_Text'].str.strip()
research_14_sna_ac['Perc5a_14'] = research_14_sna_ac['Perc5a_14'].str.strip()
research_14_sna_bc['Perc5a_14'] = research_14_sna_bc['Perc5a_14'].str.strip()
research_14_irv_ac['Perc5a_14'] = research_14_irv_ac['Perc5a_14'].str.strip()
research_14_irv_bc['Perc5a_14'] = research_14_irv_bc['Perc5a_14'].str.strip()
research_14_sna_ac['Perc7a_14'] = research_14_sna_ac['Perc7a_14'].str.strip()
research_14_sna_bc['Perc7a_14'] = research_14_sna_bc['Perc7a_14'].str.strip()
research_14_irv_ac['Perc7a_14'] = research_14_irv_ac['Perc7a_14'].str.strip()
research_14_irv_bc['Perc7a_14'] = research_14_irv_bc['Perc7a_14'].str.strip()
research_14_sna_ac['Perc9a_14'] = research_14_sna_ac['Perc9a_14'].str.strip()
research_14_sna_bc['Perc9a_14'] = research_14_sna_bc['Perc9a_14'].str.strip()
research_14_irv_ac['Perc9a_14'] = research_14_irv_ac['Perc9a_14'].str.strip()
research_14_irv_bc['Perc9a_14'] = research_14_irv_bc['Perc9a_14'].str.strip()

research_14_sna_ac_5 = research_14_sna_ac.query("`Perc5a_14` != '0.0' and `Perc5a_14` != '**'")
research_14_sna_ac_7 = research_14_sna_ac.query("`Perc7a_14` != '0.0' and `Perc7a_14` != '**'")
research_14_sna_ac_9 = research_14_sna_ac.query("`Perc9a_14` != '0.0' and `Perc9a_14` != '**'")
research_14_sna_ac_5.Perc5a_14 = research_14_sna_ac_5.Perc5a_14.astype(float)
research_14_sna_ac_7.Perc7a_14 = research_14_sna_ac_7.Perc7a_14.astype(float)
research_14_sna_ac_9.Perc9a_14 = research_14_sna_ac_9.Perc9a_14.astype(float)
research_14_sna_ac_5 = pandas.concat([research_14_sna_ac_5[research_14_sna_ac_5.Perc5a_14 > sna_14_ac_avg_5 + 10], research_14_sna_ac_5[research_14_sna_ac_5.Perc5a_14 < sna_14_ac_avg_5 - 10]], axis=0)
research_14_sna_ac_7 = pandas.concat([research_14_sna_ac_7[research_14_sna_ac_7.Perc7a_14 > sna_14_ac_avg_7 + 10], research_14_sna_ac_7[research_14_sna_ac_7.Perc7a_14 < sna_14_ac_avg_7 - 10]], axis=0)
research_14_sna_ac_9 = pandas.concat([research_14_sna_ac_9[research_14_sna_ac_9.Perc9a_14 > sna_14_ac_avg_9 + 10], research_14_sna_ac_9[research_14_sna_ac_9.Perc9a_14 < sna_14_ac_avg_9 - 10]], axis=0)

research_14_sna_bc_5 = research_14_sna_bc.query("`Perc5a_14` != '0.0' and `Perc5a_14` != '**'")
research_14_sna_bc_7 = research_14_sna_bc.query("`Perc7a_14` != '0.0' and `Perc7a_14` != '**'")
research_14_sna_bc_9 = research_14_sna_bc.query("`Perc9a_14` != '0.0' and `Perc9a_14` != '**'")
research_14_sna_bc_5.Perc5a_14 = research_14_sna_bc_5.Perc5a_14.astype(float)
research_14_sna_bc_7.Perc7a_14 = research_14_sna_bc_7.Perc7a_14.astype(float)
research_14_sna_bc_9.Perc9a_14 = research_14_sna_bc_9.Perc9a_14.astype(float)
research_14_sna_bc_5 = pandas.concat([research_14_sna_bc_5[research_14_sna_bc_5.Perc5a_14 > sna_14_bc_avg_5 + 10], research_14_sna_bc_5[research_14_sna_bc_5.Perc5a_14 < sna_14_bc_avg_5 - 10]], axis=0)
research_14_sna_bc_7 = pandas.concat([research_14_sna_bc_7[research_14_sna_bc_7.Perc7a_14 > sna_14_bc_avg_7 + 10], research_14_sna_bc_7[research_14_sna_bc_7.Perc7a_14 < sna_14_bc_avg_7 - 10]], axis=0)
research_14_sna_bc_9 = pandas.concat([research_14_sna_bc_9[research_14_sna_bc_9.Perc9a_14 > sna_14_bc_avg_9 + 10], research_14_sna_bc_9[research_14_sna_bc_9.Perc9a_14 < sna_14_bc_avg_9 - 10]], axis=0)

research_14_irv_ac_5 = research_14_irv_ac.query("`Perc5a_14` != '0.0' and `Perc5a_14` != '**'")
research_14_irv_ac_7 = research_14_irv_ac.query("`Perc7a_14` != '0.0' and `Perc7a_14` != '**'")
research_14_irv_ac_9 = research_14_irv_ac.query("`Perc9a_14` != '0.0' and `Perc9a_14` != '**'")
research_14_irv_ac_5.Perc5a_14 = research_14_irv_ac_5.Perc5a_14.astype(float)
research_14_irv_ac_7.Perc7a_14 = research_14_irv_ac_7.Perc7a_14.astype(float)
research_14_irv_ac_9.Perc9a_14 = research_14_irv_ac_9.Perc9a_14.astype(float)
research_14_irv_ac_5 = pandas.concat([research_14_irv_ac_5[research_14_irv_ac_5.Perc5a_14 > irv_14_ac_avg_5 + 10], research_14_irv_ac_5[research_14_irv_ac_5.Perc5a_14 < irv_14_ac_avg_5 - 10]], axis=0)
research_14_irv_ac_7 = pandas.concat([research_14_irv_ac_7[research_14_irv_ac_7.Perc7a_14 > irv_14_ac_avg_7 + 10], research_14_irv_ac_7[research_14_irv_ac_7.Perc7a_14 < irv_14_ac_avg_7 - 10]], axis=0)
research_14_irv_ac_9 = pandas.concat([research_14_irv_ac_9[research_14_irv_ac_9.Perc9a_14 > irv_14_ac_avg_9 + 10], research_14_irv_ac_9[research_14_irv_ac_9.Perc9a_14 < irv_14_ac_avg_9 - 10]], axis=0)

research_14_irv_bc_5 = research_14_irv_bc.query("`Perc5a_14` != '0.0' and `Perc5a_14` != '**'")
research_14_irv_bc_7 = research_14_irv_bc.query("`Perc7a_14` != '0.0' and `Perc7a_14` != '**'")
research_14_irv_bc_9 = research_14_irv_bc.query("`Perc9a_14` != '0.0' and `Perc9a_14` != '**'")
research_14_irv_bc_5.Perc5a_14 = research_14_irv_bc_5.Perc5a_14.astype(float)
research_14_irv_bc_7.Perc7a_14 = research_14_irv_bc_7.Perc7a_14.astype(float)
research_14_irv_bc_9.Perc9a_14 = research_14_irv_bc_9.Perc9a_14.astype(float)
research_14_irv_bc_5 = pandas.concat([research_14_irv_bc_5[research_14_irv_bc_5.Perc5a_14 > irv_14_bc_avg_5 + 10], research_14_irv_bc_5[research_14_irv_bc_5.Perc5a_14 < irv_14_bc_avg_5 - 10]], axis=0)
research_14_irv_bc_7 = pandas.concat([research_14_irv_bc_7[research_14_irv_bc_7.Perc7a_14 > irv_14_bc_avg_7 + 10], research_14_irv_bc_7[research_14_irv_bc_7.Perc7a_14 < irv_14_bc_avg_7 - 10]], axis=0)
research_14_irv_bc_9 = pandas.concat([research_14_irv_bc_9[research_14_irv_bc_9.Perc9a_14 > irv_14_bc_avg_9 + 10], research_14_irv_bc_9[research_14_irv_bc_9.Perc9a_14 < irv_14_bc_avg_9 - 10]], axis=0)
# Out:
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\2429022093.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_14_sna_ac['Line_Text'] = research_14_sna_ac['Line_Text'].str.strip()
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\2429022093.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_14_sna_bc['Line_Text'] = research_14_sna_bc['Line_Text'].str.strip()
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\2429022093.py:9: SettingWithCopyWarning:
# ...

# %%
research_11 = pandas.read_csv("researchoutput11.txt",dtype=str,index_col=False)
research_11.rename(columns = {'CO': 'ccode', 'DIST':'dcode', 'SCHL':'scode', 'ChrtNum':'chrtnum', 'Perc5a':'Perc5a_11', 'Perc7a':'Perc7a_11', 'Perc9a':'Perc9a_11'}, inplace = True)
research_11_sna_ac = research_11.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")
research_11_sna_bc = research_11.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")
research_11_irv_ac = research_11.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")
research_11_irv_bc = research_11.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")
research_11_sna_ac['Line_Text'] = research_11_sna_ac['Line_Text'].str.strip()
research_11_sna_bc['Line_Text'] = research_11_sna_bc['Line_Text'].str.strip()
research_11_irv_ac['Line_Text'] = research_11_irv_ac['Line_Text'].str.strip()
research_11_irv_bc['Line_Text'] = research_11_irv_bc['Line_Text'].str.strip()
research_11_sna_ac['Perc5a_11'] = research_11_sna_ac['Perc5a_11'].str.strip()
research_11_sna_bc['Perc5a_11'] = research_11_sna_bc['Perc5a_11'].str.strip()
research_11_irv_ac['Perc5a_11'] = research_11_irv_ac['Perc5a_11'].str.strip()
research_11_irv_bc['Perc5a_11'] = research_11_irv_bc['Perc5a_11'].str.strip()
research_11_sna_ac['Perc7a_11'] = research_11_sna_ac['Perc7a_11'].str.strip()
research_11_sna_bc['Perc7a_11'] = research_11_sna_bc['Perc7a_11'].str.strip()
research_11_irv_ac['Perc7a_11'] = research_11_irv_ac['Perc7a_11'].str.strip()
research_11_irv_bc['Perc7a_11'] = research_11_irv_bc['Perc7a_11'].str.strip()
research_11_sna_ac['Perc9a_11'] = research_11_sna_ac['Perc9a_11'].str.strip()
research_11_sna_bc['Perc9a_11'] = research_11_sna_bc['Perc9a_11'].str.strip()
research_11_irv_ac['Perc9a_11'] = research_11_irv_ac['Perc9a_11'].str.strip()
research_11_irv_bc['Perc9a_11'] = research_11_irv_bc['Perc9a_11'].str.strip()

research_11_sna_ac_5 = research_11_sna_ac.query("`Perc5a_11` != '0.0' and `Perc5a_11` != '**'")
research_11_sna_ac_7 = research_11_sna_ac.query("`Perc7a_11` != '0.0' and `Perc7a_11` != '**'")
research_11_sna_ac_9 = research_11_sna_ac.query("`Perc9a_11` != '0.0' and `Perc9a_11` != '**'")
research_11_sna_ac_5.Perc5a_11 = research_11_sna_ac_5.Perc5a_11.astype(float)
research_11_sna_ac_7.Perc7a_11 = research_11_sna_ac_7.Perc7a_11.astype(float)
research_11_sna_ac_9.Perc9a_11 = research_11_sna_ac_9.Perc9a_11.astype(float)
research_11_sna_ac_5 = pandas.concat([research_11_sna_ac_5[research_11_sna_ac_5.Perc5a_11 > sna_11_ac_avg_5 + 10], research_11_sna_ac_5[research_11_sna_ac_5.Perc5a_11 < sna_11_ac_avg_5 - 10]], axis=0)
research_11_sna_ac_7 = pandas.concat([research_11_sna_ac_7[research_11_sna_ac_7.Perc7a_11 > sna_11_ac_avg_7 + 10], research_11_sna_ac_7[research_11_sna_ac_7.Perc7a_11 < sna_11_ac_avg_7 - 10]], axis=0)
research_11_sna_ac_9 = pandas.concat([research_11_sna_ac_9[research_11_sna_ac_9.Perc9a_11 > sna_11_ac_avg_9 + 10], research_11_sna_ac_9[research_11_sna_ac_9.Perc9a_11 < sna_11_ac_avg_9 - 10]], axis=0)

research_11_sna_bc_5 = research_11_sna_bc.query("`Perc5a_11` != '0.0' and `Perc5a_11` != '**'")
research_11_sna_bc_7 = research_11_sna_bc.query("`Perc7a_11` != '0.0' and `Perc7a_11` != '**'")
research_11_sna_bc_9 = research_11_sna_bc.query("`Perc9a_11` != '0.0' and `Perc9a_11` != '**'")
research_11_sna_bc_5.Perc5a_11 = research_11_sna_bc_5.Perc5a_11.astype(float)
research_11_sna_bc_7.Perc7a_11 = research_11_sna_bc_7.Perc7a_11.astype(float)
research_11_sna_bc_9.Perc9a_11 = research_11_sna_bc_9.Perc9a_11.astype(float)
research_11_sna_bc_5 = pandas.concat([research_11_sna_bc_5[research_11_sna_bc_5.Perc5a_11 > sna_11_bc_avg_5 + 10], research_11_sna_bc_5[research_11_sna_bc_5.Perc5a_11 < sna_11_bc_avg_5 - 10]], axis=0)
research_11_sna_bc_7 = pandas.concat([research_11_sna_bc_7[research_11_sna_bc_7.Perc7a_11 > sna_11_bc_avg_7 + 10], research_11_sna_bc_7[research_11_sna_bc_7.Perc7a_11 < sna_11_bc_avg_7 - 10]], axis=0)
research_11_sna_bc_9 = pandas.concat([research_11_sna_bc_9[research_11_sna_bc_9.Perc9a_11 > sna_11_bc_avg_9 + 10], research_11_sna_bc_9[research_11_sna_bc_9.Perc9a_11 < sna_11_bc_avg_9 - 10]], axis=0)

research_11_irv_ac_5 = research_11_irv_ac.query("`Perc5a_11` != '0.0' and `Perc5a_11` != '**'")
research_11_irv_ac_7 = research_11_irv_ac.query("`Perc7a_11` != '0.0' and `Perc7a_11` != '**'")
research_11_irv_ac_9 = research_11_irv_ac.query("`Perc9a_11` != '0.0' and `Perc9a_11` != '**'")
research_11_irv_ac_5.Perc5a_11 = research_11_irv_ac_5.Perc5a_11.astype(float)
research_11_irv_ac_7.Perc7a_11 = research_11_irv_ac_7.Perc7a_11.astype(float)
research_11_irv_ac_9.Perc9a_11 = research_11_irv_ac_9.Perc9a_11.astype(float)
research_11_irv_ac_5 = pandas.concat([research_11_irv_ac_5[research_11_irv_ac_5.Perc5a_11 > irv_11_ac_avg_5 + 10], research_11_irv_ac_5[research_11_irv_ac_5.Perc5a_11 < irv_11_ac_avg_5 - 10]], axis=0)
research_11_irv_ac_7 = pandas.concat([research_11_irv_ac_7[research_11_irv_ac_7.Perc7a_11 > irv_11_ac_avg_7 + 10], research_11_irv_ac_7[research_11_irv_ac_7.Perc7a_11 < irv_11_ac_avg_7 - 10]], axis=0)
research_11_irv_ac_9 = pandas.concat([research_11_irv_ac_9[research_11_irv_ac_9.Perc9a_11 > irv_11_ac_avg_9 + 10], research_11_irv_ac_9[research_11_irv_ac_9.Perc9a_11 < irv_11_ac_avg_9 - 10]], axis=0)

research_11_irv_bc_5 = research_11_irv_bc.query("`Perc5a_11` != '0.0' and `Perc5a_11` != '**'")
research_11_irv_bc_7 = research_11_irv_bc.query("`Perc7a_11` != '0.0' and `Perc7a_11` != '**'")
research_11_irv_bc_9 = research_11_irv_bc.query("`Perc9a_11` != '0.0' and `Perc9a_11` != '**'")
research_11_irv_bc_5.Perc5a_11 = research_11_irv_bc_5.Perc5a_11.astype(float)
research_11_irv_bc_7.Perc7a_11 = research_11_irv_bc_7.Perc7a_11.astype(float)
research_11_irv_bc_9.Perc9a_11 = research_11_irv_bc_9.Perc9a_11.astype(float)
research_11_irv_bc_5 = pandas.concat([research_11_irv_bc_5[research_11_irv_bc_5.Perc5a_11 > irv_11_bc_avg_5 + 10], research_11_irv_bc_5[research_11_irv_bc_5.Perc5a_11 < irv_11_bc_avg_5 - 10]], axis=0)
research_11_irv_bc_7 = pandas.concat([research_11_irv_bc_7[research_11_irv_bc_7.Perc7a_11 > irv_11_bc_avg_7 + 10], research_11_irv_bc_7[research_11_irv_bc_7.Perc7a_11 < irv_11_bc_avg_7 - 10]], axis=0)
research_11_irv_bc_9 = pandas.concat([research_11_irv_bc_9[research_11_irv_bc_9.Perc9a_11 > irv_11_bc_avg_9 + 10], research_11_irv_bc_9[research_11_irv_bc_9.Perc9a_11 < irv_11_bc_avg_9 - 10]], axis=0)
# Out:
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\3244404859.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_11_sna_ac['Line_Text'] = research_11_sna_ac['Line_Text'].str.strip()
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\3244404859.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_11_sna_bc['Line_Text'] = research_11_sna_bc['Line_Text'].str.strip()
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\3244404859.py:9: SettingWithCopyWarning:
# ...

# %%
# research_10 = pandas.read_csv("researchoutput10.txt",dtype=str,index_col=False)
# research_10.rename(columns = {'Level': 'Level_Number', 'charternum':'chrtnum', 'Gr5PctIn':'Perc5a_10', 'Gr7PctIn':'Perc7a_10', 'Gr9PctIn':'Perc9a_10', 'RptType':'Report_Number', 'line_num':
#                              'Line_Number', 'SubGrp': 'Table_Number'}, inplace = True)
# research_10_sna_ac = research_10.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '1' and `Table_Number` == '0' and `Line_Number` == '1'")
# research_10_sna_bc = research_10.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '1' and `Table_Number` == '0' and `Line_Number` == '2'")
# research_10_irv_ac = research_10.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '1' and `Table_Number` == '0' and `Line_Number` == '1'")
# research_10_irv_bc = research_10.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '1' and `Table_Number` == '0' and `Line_Number` == '2'")

# %%
# research_10_sna_ac

# %%
research_13 = pandas.read_csv("2012_13_ResearchFile.txt",sep='\t',dtype=str,index_col=False)
research_13.rename(columns = {'CO': 'ccode', 'DIST':'dcode', 'SCHL':'scode', 'ChrtNum':'chrtnum', 'Perc5a':'Perc5a_13', 'Perc7a':'Perc7a_13', 'Perc9a':'Perc9a_13'}, inplace = True)
research_13_sna_ac = research_13.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")
research_13_sna_bc = research_13.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")
research_13_irv_ac = research_13.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")
research_13_irv_bc = research_13.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")
research_13_sna_ac['Line_Text'] = research_13_sna_ac['Line_Text'].str.strip()
research_13_sna_bc['Line_Text'] = research_13_sna_bc['Line_Text'].str.strip()
research_13_irv_ac['Line_Text'] = research_13_irv_ac['Line_Text'].str.strip()
research_13_irv_bc['Line_Text'] = research_13_irv_bc['Line_Text'].str.strip()
research_13_sna_ac['Perc5a_13'] = research_13_sna_ac['Perc5a_13'].str.strip()
research_13_sna_bc['Perc5a_13'] = research_13_sna_bc['Perc5a_13'].str.strip()
research_13_irv_ac['Perc5a_13'] = research_13_irv_ac['Perc5a_13'].str.strip()
research_13_irv_bc['Perc5a_13'] = research_13_irv_bc['Perc5a_13'].str.strip()
research_13_sna_ac['Perc7a_13'] = research_13_sna_ac['Perc7a_13'].str.strip()
research_13_sna_bc['Perc7a_13'] = research_13_sna_bc['Perc7a_13'].str.strip()
research_13_irv_ac['Perc7a_13'] = research_13_irv_ac['Perc7a_13'].str.strip()
research_13_irv_bc['Perc7a_13'] = research_13_irv_bc['Perc7a_13'].str.strip()
research_13_sna_ac['Perc9a_13'] = research_13_sna_ac['Perc9a_13'].str.strip()
research_13_sna_bc['Perc9a_13'] = research_13_sna_bc['Perc9a_13'].str.strip()
research_13_irv_ac['Perc9a_13'] = research_13_irv_ac['Perc9a_13'].str.strip()
research_13_irv_bc['Perc9a_13'] = research_13_irv_bc['Perc9a_13'].str.strip()

research_13_sna_ac_5 = research_13_sna_ac.query("`Perc5a_13` != '0.0' and `Perc5a_13` != '**'")
research_13_sna_ac_7 = research_13_sna_ac.query("`Perc7a_13` != '0.0' and `Perc7a_13` != '**'")
research_13_sna_ac_9 = research_13_sna_ac.query("`Perc9a_13` != '0.0' and `Perc9a_13` != '**'")
research_13_sna_ac_5.Perc5a_13 = research_13_sna_ac_5.Perc5a_13.astype(float)
research_13_sna_ac_7.Perc7a_13 = research_13_sna_ac_7.Perc7a_13.astype(float)
research_13_sna_ac_9.Perc9a_13 = research_13_sna_ac_9.Perc9a_13.astype(float)
research_13_sna_ac_5 = pandas.concat([research_13_sna_ac_5[research_13_sna_ac_5.Perc5a_13 > sna_13_ac_avg_5 + 10], research_13_sna_ac_5[research_13_sna_ac_5.Perc5a_13 < sna_13_ac_avg_5 - 10]], axis=0)
research_13_sna_ac_7 = pandas.concat([research_13_sna_ac_7[research_13_sna_ac_7.Perc7a_13 > sna_13_ac_avg_7 + 10], research_13_sna_ac_7[research_13_sna_ac_7.Perc7a_13 < sna_13_ac_avg_7 - 10]], axis=0)
research_13_sna_ac_9 = pandas.concat([research_13_sna_ac_9[research_13_sna_ac_9.Perc9a_13 > sna_13_ac_avg_9 + 10], research_13_sna_ac_9[research_13_sna_ac_9.Perc9a_13 < sna_13_ac_avg_9 - 10]], axis=0)

research_13_sna_bc_5 = research_13_sna_bc.query("`Perc5a_13` != '0.0' and `Perc5a_13` != '**'")
research_13_sna_bc_7 = research_13_sna_bc.query("`Perc7a_13` != '0.0' and `Perc7a_13` != '**'")
research_13_sna_bc_9 = research_13_sna_bc.query("`Perc9a_13` != '0.0' and `Perc9a_13` != '**'")
research_13_sna_bc_5.Perc5a_13 = research_13_sna_bc_5.Perc5a_13.astype(float)
research_13_sna_bc_7.Perc7a_13 = research_13_sna_bc_7.Perc7a_13.astype(float)
research_13_sna_bc_9.Perc9a_13 = research_13_sna_bc_9.Perc9a_13.astype(float)
research_13_sna_bc_5 = pandas.concat([research_13_sna_bc_5[research_13_sna_bc_5.Perc5a_13 > sna_13_bc_avg_5 + 10], research_13_sna_bc_5[research_13_sna_bc_5.Perc5a_13 < sna_13_bc_avg_5 - 10]], axis=0)
research_13_sna_bc_7 = pandas.concat([research_13_sna_bc_7[research_13_sna_bc_7.Perc7a_13 > sna_13_bc_avg_7 + 10], research_13_sna_bc_7[research_13_sna_bc_7.Perc7a_13 < sna_13_bc_avg_7 - 10]], axis=0)
research_13_sna_bc_9 = pandas.concat([research_13_sna_bc_9[research_13_sna_bc_9.Perc9a_13 > sna_13_bc_avg_9 + 10], research_13_sna_bc_9[research_13_sna_bc_9.Perc9a_13 < sna_13_bc_avg_9 - 10]], axis=0)

research_13_irv_ac_5 = research_13_irv_ac.query("`Perc5a_13` != '0.0' and `Perc5a_13` != '**'")
research_13_irv_ac_7 = research_13_irv_ac.query("`Perc7a_13` != '0.0' and `Perc7a_13` != '**'")
research_13_irv_ac_9 = research_13_irv_ac.query("`Perc9a_13` != '0.0' and `Perc9a_13` != '**'")
research_13_irv_ac_5.Perc5a_13 = research_13_irv_ac_5.Perc5a_13.astype(float)
research_13_irv_ac_7.Perc7a_13 = research_13_irv_ac_7.Perc7a_13.astype(float)
research_13_irv_ac_9.Perc9a_13 = research_13_irv_ac_9.Perc9a_13.astype(float)
research_13_irv_ac_5 = pandas.concat([research_13_irv_ac_5[research_13_irv_ac_5.Perc5a_13 > irv_13_ac_avg_5 + 10], research_13_irv_ac_5[research_13_irv_ac_5.Perc5a_13 < irv_13_ac_avg_5 - 10]], axis=0)
research_13_irv_ac_7 = pandas.concat([research_13_irv_ac_7[research_13_irv_ac_7.Perc7a_13 > irv_13_ac_avg_7 + 10], research_13_irv_ac_7[research_13_irv_ac_7.Perc7a_13 < irv_13_ac_avg_7 - 10]], axis=0)
research_13_irv_ac_9 = pandas.concat([research_13_irv_ac_9[research_13_irv_ac_9.Perc9a_13 > irv_13_ac_avg_9 + 10], research_13_irv_ac_9[research_13_irv_ac_9.Perc9a_13 < irv_13_ac_avg_9 - 10]], axis=0)

research_13_irv_bc_5 = research_13_irv_bc.query("`Perc5a_13` != '0.0' and `Perc5a_13` != '**'")
research_13_irv_bc_7 = research_13_irv_bc.query("`Perc7a_13` != '0.0' and `Perc7a_13` != '**'")
research_13_irv_bc_9 = research_13_irv_bc.query("`Perc9a_13` != '0.0' and `Perc9a_13` != '**'")
research_13_irv_bc_5.Perc5a_13 = research_13_irv_bc_5.Perc5a_13.astype(float)
research_13_irv_bc_7.Perc7a_13 = research_13_irv_bc_7.Perc7a_13.astype(float)
research_13_irv_bc_9.Perc9a_13 = research_13_irv_bc_9.Perc9a_13.astype(float)
research_13_irv_bc_5 = pandas.concat([research_13_irv_bc_5[research_13_irv_bc_5.Perc5a_13 > irv_13_bc_avg_5 + 10], research_13_irv_bc_5[research_13_irv_bc_5.Perc5a_13 < irv_13_bc_avg_5 - 10]], axis=0)
research_13_irv_bc_7 = pandas.concat([research_13_irv_bc_7[research_13_irv_bc_7.Perc7a_13 > irv_13_bc_avg_7 + 10], research_13_irv_bc_7[research_13_irv_bc_7.Perc7a_13 < irv_13_bc_avg_7 - 10]], axis=0)
research_13_irv_bc_9 = pandas.concat([research_13_irv_bc_9[research_13_irv_bc_9.Perc9a_13 > irv_13_bc_avg_9 + 10], research_13_irv_bc_9[research_13_irv_bc_9.Perc9a_13 < irv_13_bc_avg_9 - 10]], axis=0)
# Out:
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\3681171935.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_13_sna_ac['Line_Text'] = research_13_sna_ac['Line_Text'].str.strip()
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\3681171935.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_13_sna_bc['Line_Text'] = research_13_sna_bc['Line_Text'].str.strip()
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\3681171935.py:9: SettingWithCopyWarning:
# ...

# %%
research_11_irv_ac_9
# Out:
# Empty DataFrame
# Columns: [ID, Level_Number, Report_Number, Table_Number, Line_Number, ccode, dcode, scode, Line_Text, NoStud5, NoHFZ5, Perc5a_11, Perc5b, Perc5c, NoStud7, NoHFZ7, Perc7a_11, Perc7b, Perc7c, NoStud9, NoHFZ9, Perc9a_11, Perc9b, Perc9c, chrtnum]
# Index: []
#
# [0 rows x 25 columns]

# %%
research_12 = pandas.read_csv("2011_12_ResearchFile.txt",sep='\t',dtype=str,index_col=False)
research_12.rename(columns = {'CO': 'ccode', 'DIST':'dcode', 'SCHL':'scode', 'ChrtNum':'chrtnum', 'Perc5a':'Perc5a_12', 'Perc7a':'Perc7a_12', 'Perc9a':'Perc9a_12'}, inplace = True)
research_12_sna_ac = research_12.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")
research_12_sna_bc = research_12.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '66670' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")
research_12_irv_ac = research_12.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '1'")
research_12_irv_bc = research_12.query("`scode` != '0000000' and `scode` != '0000001' and `dcode` == '73650' and `chrtnum` == '0000' and `Level_Number` == '1' and `Report_Number` == '0' and `Table_Number` == '1' and `Line_Number` == '2'")
research_12_sna_ac['Line_Text'] = research_12_sna_ac['Line_Text'].str.strip()
research_12_sna_bc['Line_Text'] = research_12_sna_bc['Line_Text'].str.strip()
research_12_irv_ac['Line_Text'] = research_12_irv_ac['Line_Text'].str.strip()
research_12_irv_bc['Line_Text'] = research_12_irv_bc['Line_Text'].str.strip()
research_12_sna_ac['Perc5a_12'] = research_12_sna_ac['Perc5a_12'].str.strip()
research_12_sna_bc['Perc5a_12'] = research_12_sna_bc['Perc5a_12'].str.strip()
research_12_irv_ac['Perc5a_12'] = research_12_irv_ac['Perc5a_12'].str.strip()
research_12_irv_bc['Perc5a_12'] = research_12_irv_bc['Perc5a_12'].str.strip()
research_12_sna_ac['Perc7a_12'] = research_12_sna_ac['Perc7a_12'].str.strip()
research_12_sna_bc['Perc7a_12'] = research_12_sna_bc['Perc7a_12'].str.strip()
research_12_irv_ac['Perc7a_12'] = research_12_irv_ac['Perc7a_12'].str.strip()
research_12_irv_bc['Perc7a_12'] = research_12_irv_bc['Perc7a_12'].str.strip()
research_12_sna_ac['Perc9a_12'] = research_12_sna_ac['Perc9a_12'].str.strip()
research_12_sna_bc['Perc9a_12'] = research_12_sna_bc['Perc9a_12'].str.strip()
research_12_irv_ac['Perc9a_12'] = research_12_irv_ac['Perc9a_12'].str.strip()
research_12_irv_bc['Perc9a_12'] = research_12_irv_bc['Perc9a_12'].str.strip()

research_12_sna_ac_5 = research_12_sna_ac.query("`Perc5a_12` != '0.0' and `Perc5a_12` != '**'")
research_12_sna_ac_7 = research_12_sna_ac.query("`Perc7a_12` != '0.0' and `Perc7a_12` != '**'")
research_12_sna_ac_9 = research_12_sna_ac.query("`Perc9a_12` != '0.0' and `Perc9a_12` != '**'")
research_12_sna_ac_5.Perc5a_12 = research_12_sna_ac_5.Perc5a_12.astype(float)
research_12_sna_ac_7.Perc7a_12 = research_12_sna_ac_7.Perc7a_12.astype(float)
research_12_sna_ac_9.Perc9a_12 = research_12_sna_ac_9.Perc9a_12.astype(float)
research_12_sna_ac_5 = pandas.concat([research_12_sna_ac_5[research_12_sna_ac_5.Perc5a_12 > sna_12_ac_avg_5 + 10], research_12_sna_ac_5[research_12_sna_ac_5.Perc5a_12 < sna_12_ac_avg_5 - 10]], axis=0)
research_12_sna_ac_7 = pandas.concat([research_12_sna_ac_7[research_12_sna_ac_7.Perc7a_12 > sna_12_ac_avg_7 + 10], research_12_sna_ac_7[research_12_sna_ac_7.Perc7a_12 < sna_12_ac_avg_7 - 10]], axis=0)
research_12_sna_ac_9 = pandas.concat([research_12_sna_ac_9[research_12_sna_ac_9.Perc9a_12 > sna_12_ac_avg_9 + 10], research_12_sna_ac_9[research_12_sna_ac_9.Perc9a_12 < sna_12_ac_avg_9 - 10]], axis=0)

research_12_sna_bc_5 = research_12_sna_bc.query("`Perc5a_12` != '0.0' and `Perc5a_12` != '**'")
research_12_sna_bc_7 = research_12_sna_bc.query("`Perc7a_12` != '0.0' and `Perc7a_12` != '**'")
research_12_sna_bc_9 = research_12_sna_bc.query("`Perc9a_12` != '0.0' and `Perc9a_12` != '**'")
research_12_sna_bc_5.Perc5a_12 = research_12_sna_bc_5.Perc5a_12.astype(float)
research_12_sna_bc_7.Perc7a_12 = research_12_sna_bc_7.Perc7a_12.astype(float)
research_12_sna_bc_9.Perc9a_12 = research_12_sna_bc_9.Perc9a_12.astype(float)
research_12_sna_bc_5 = pandas.concat([research_12_sna_bc_5[research_12_sna_bc_5.Perc5a_12 > sna_12_bc_avg_5 + 10], research_12_sna_bc_5[research_12_sna_bc_5.Perc5a_12 < sna_12_bc_avg_5 - 10]], axis=0)
research_12_sna_bc_7 = pandas.concat([research_12_sna_bc_7[research_12_sna_bc_7.Perc7a_12 > sna_12_bc_avg_7 + 10], research_12_sna_bc_7[research_12_sna_bc_7.Perc7a_12 < sna_12_bc_avg_7 - 10]], axis=0)
research_12_sna_bc_9 = pandas.concat([research_12_sna_bc_9[research_12_sna_bc_9.Perc9a_12 > sna_12_bc_avg_9 + 10], research_12_sna_bc_9[research_12_sna_bc_9.Perc9a_12 < sna_12_bc_avg_9 - 10]], axis=0)

research_12_irv_ac_5 = research_12_irv_ac.query("`Perc5a_12` != '0.0' and `Perc5a_12` != '**'")
research_12_irv_ac_7 = research_12_irv_ac.query("`Perc7a_12` != '0.0' and `Perc7a_12` != '**'")
research_12_irv_ac_9 = research_12_irv_ac.query("`Perc9a_12` != '0.0' and `Perc9a_12` != '**'")
research_12_irv_ac_5.Perc5a_12 = research_12_irv_ac_5.Perc5a_12.astype(float)
research_12_irv_ac_7.Perc7a_12 = research_12_irv_ac_7.Perc7a_12.astype(float)
research_12_irv_ac_9.Perc9a_12 = research_12_irv_ac_9.Perc9a_12.astype(float)
research_12_irv_ac_5 = pandas.concat([research_12_irv_ac_5[research_12_irv_ac_5.Perc5a_12 > irv_12_ac_avg_5 + 10], research_12_irv_ac_5[research_12_irv_ac_5.Perc5a_12 < irv_12_ac_avg_5 - 10]], axis=0)
research_12_irv_ac_7 = pandas.concat([research_12_irv_ac_7[research_12_irv_ac_7.Perc7a_12 > irv_12_ac_avg_7 + 10], research_12_irv_ac_7[research_12_irv_ac_7.Perc7a_12 < irv_12_ac_avg_7 - 10]], axis=0)
research_12_irv_ac_9 = pandas.concat([research_12_irv_ac_9[research_12_irv_ac_9.Perc9a_12 > irv_12_ac_avg_9 + 10], research_12_irv_ac_9[research_12_irv_ac_9.Perc9a_12 < irv_12_ac_avg_9 - 10]], axis=0)

research_12_irv_bc_5 = research_12_irv_bc.query("`Perc5a_12` != '0.0' and `Perc5a_12` != '**'")
research_12_irv_bc_7 = research_12_irv_bc.query("`Perc7a_12` != '0.0' and `Perc7a_12` != '**'")
research_12_irv_bc_9 = research_12_irv_bc.query("`Perc9a_12` != '0.0' and `Perc9a_12` != '**'")
research_12_irv_bc_5.Perc5a_12 = research_12_irv_bc_5.Perc5a_12.astype(float)
research_12_irv_bc_7.Perc7a_12 = research_12_irv_bc_7.Perc7a_12.astype(float)
research_12_irv_bc_9.Perc9a_12 = research_12_irv_bc_9.Perc9a_12.astype(float)
research_12_irv_bc_5 = pandas.concat([research_12_irv_bc_5[research_12_irv_bc_5.Perc5a_12 > irv_12_bc_avg_5 + 10], research_12_irv_bc_5[research_12_irv_bc_5.Perc5a_12 < irv_12_bc_avg_5 - 10]], axis=0)
research_12_irv_bc_7 = pandas.concat([research_12_irv_bc_7[research_12_irv_bc_7.Perc7a_12 > irv_12_bc_avg_7 + 10], research_12_irv_bc_7[research_12_irv_bc_7.Perc7a_12 < irv_12_bc_avg_7 - 10]], axis=0)
research_12_irv_bc_9 = pandas.concat([research_12_irv_bc_9[research_12_irv_bc_9.Perc9a_12 > irv_12_bc_avg_9 + 10], research_12_irv_bc_9[research_12_irv_bc_9.Perc9a_12 < irv_12_bc_avg_9 - 10]], axis=0)
# Out:
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\2493523974.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_12_sna_ac['Line_Text'] = research_12_sna_ac['Line_Text'].str.strip()
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\2493523974.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   research_12_sna_bc['Line_Text'] = research_12_sna_bc['Line_Text'].str.strip()
# C:\Users\hky\AppData\Local\Temp\ipykernel_10128\2493523974.py:9: SettingWithCopyWarning:
# ...

# %%
research_12_irv_bc_7
# Out:
#         Level_Number Report_Number Table_Number Line_Number ccode  dcode  \
# 1788508            1             0            1           2    30  73650
#
#            scode         Line_Text NoStud5 NoHFZ5  ... NoHFZ7 Perc7a_12  \
# 1788508  6094718  Body Composition      96     71  ...     54      61.4
#
#         Perc7b Perc7c NoStud9  NoHFZ9 Perc9a_12 Perc9b Perc9c chrtnum
# 1788508   17.0   21.6       0       0       0.0    0.0    0.0    0000
#
# [1 rows x 24 columns]

# %%
sna_ac_5 = pandas.merge(entities_sna, research_19_sna_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

# %%
sna_ac_5
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County           District  \
# 0     30  66670    0000  0108365  30666700108365  Orange  Santa Ana Unified
# 1     30  66670    0000  0108373  30666700108373  Orange  Santa Ana Unified
# 2     30  66670    0000  0114736  30666700114736  Orange  Santa Ana Unified
# 3     30  66670    0000  0116582  30666700116582  Orange  Santa Ana Unified
# 4     30  66670    0000  0135897  30666700135897  Orange  Santa Ana Unified
# 5     30  66670    0000  3030491  30666703030491  Orange  Santa Ana Unified
# 6     30  66670    0000  3030608  30666703030608  Orange  Santa Ana Unified
# 7     30  66670    0000  3035821  30666703035821  Orange  Santa Ana Unified
# 8     30  66670    0000  3036357  30666703036357  Orange  Santa Ana Unified
# 9     30  66670    0000  3036456  30666703036456  Orange  Santa Ana Unified
# 10    30  66670    0000  6030209  30666706030209  Orange  Santa Ana Unified
# ...

# %%
sna_ac_5 = sna_ac_5.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_19','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_19','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])

# %%
sna_ac_5
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County           District  \
# 0     30  66670    0000  0108365  30666700108365  Orange  Santa Ana Unified
# 1     30  66670    0000  0108373  30666700108373  Orange  Santa Ana Unified
# 2     30  66670    0000  0114736  30666700114736  Orange  Santa Ana Unified
# 3     30  66670    0000  0116582  30666700116582  Orange  Santa Ana Unified
# 4     30  66670    0000  0135897  30666700135897  Orange  Santa Ana Unified
# 5     30  66670    0000  3030491  30666703030491  Orange  Santa Ana Unified
# 6     30  66670    0000  3030608  30666703030608  Orange  Santa Ana Unified
# 7     30  66670    0000  3035821  30666703035821  Orange  Santa Ana Unified
# 8     30  66670    0000  3036357  30666703036357  Orange  Santa Ana Unified
# 9     30  66670    0000  3036456  30666703036456  Orange  Santa Ana Unified
# 10    30  66670    0000  6030209  30666706030209  Orange  Santa Ana Unified
# ...

# %%
research_18_sna_ac_5 = research_18_sna_ac_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_18','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_18','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_5 = pandas.merge(sna_ac_5, research_18_sna_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
sna_ac_5
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County           District  \
# 0     30  66670    0000  0108365  30666700108365  Orange  Santa Ana Unified
# 1     30  66670    0000  0108373  30666700108373  Orange  Santa Ana Unified
# 2     30  66670    0000  0114736  30666700114736  Orange  Santa Ana Unified
# 3     30  66670    0000  0116582  30666700116582  Orange  Santa Ana Unified
# 4     30  66670    0000  0135897  30666700135897  Orange  Santa Ana Unified
# 5     30  66670    0000  3030491  30666703030491  Orange  Santa Ana Unified
# 6     30  66670    0000  3030608  30666703030608  Orange  Santa Ana Unified
# 7     30  66670    0000  3035821  30666703035821  Orange  Santa Ana Unified
# 8     30  66670    0000  3036357  30666703036357  Orange  Santa Ana Unified
# 9     30  66670    0000  3036456  30666703036456  Orange  Santa Ana Unified
# 10    30  66670    0000  6030209  30666706030209  Orange  Santa Ana Unified
# ...

# %%
research_17_sna_ac_5 = research_17_sna_ac_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_17','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_17','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_5 = pandas.merge(sna_ac_5, research_17_sna_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
sna_ac_5
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County           District  \
# 0     30  66670    0000  0108365  30666700108365  Orange  Santa Ana Unified
# 1     30  66670    0000  0108373  30666700108373  Orange  Santa Ana Unified
# 2     30  66670    0000  0114736  30666700114736  Orange  Santa Ana Unified
# 3     30  66670    0000  0116582  30666700116582  Orange  Santa Ana Unified
# 4     30  66670    0000  0135897  30666700135897  Orange  Santa Ana Unified
# 5     30  66670    0000  3030491  30666703030491  Orange  Santa Ana Unified
# 6     30  66670    0000  3030608  30666703030608  Orange  Santa Ana Unified
# 7     30  66670    0000  3035821  30666703035821  Orange  Santa Ana Unified
# 8     30  66670    0000  3036357  30666703036357  Orange  Santa Ana Unified
# 9     30  66670    0000  3036456  30666703036456  Orange  Santa Ana Unified
# 10    30  66670    0000  6030209  30666706030209  Orange  Santa Ana Unified
# ...

# %%
research_16_sna_ac_5 = research_16_sna_ac_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_16','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_16','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_5 = pandas.merge(sna_ac_5, research_16_sna_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
sna_ac_5
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County           District  \
# 0     30  66670    0000  0108365  30666700108365  Orange  Santa Ana Unified
# 1     30  66670    0000  0108373  30666700108373  Orange  Santa Ana Unified
# 2     30  66670    0000  0114736  30666700114736  Orange  Santa Ana Unified
# 3     30  66670    0000  0116582  30666700116582  Orange  Santa Ana Unified
# 4     30  66670    0000  0135897  30666700135897  Orange  Santa Ana Unified
# 5     30  66670    0000  3030491  30666703030491  Orange  Santa Ana Unified
# 6     30  66670    0000  3030608  30666703030608  Orange  Santa Ana Unified
# 7     30  66670    0000  3035821  30666703035821  Orange  Santa Ana Unified
# 8     30  66670    0000  3036357  30666703036357  Orange  Santa Ana Unified
# 9     30  66670    0000  3036456  30666703036456  Orange  Santa Ana Unified
# 10    30  66670    0000  6030209  30666706030209  Orange  Santa Ana Unified
# ...

# %%
research_15_sna_ac_5 = research_15_sna_ac_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_15','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_15','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_5 = pandas.merge(sna_ac_5, research_15_sna_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
sna_ac_5
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County           District  \
# 0     30  66670    0000  0108365  30666700108365  Orange  Santa Ana Unified
# 1     30  66670    0000  0108373  30666700108373  Orange  Santa Ana Unified
# 2     30  66670    0000  0114736  30666700114736  Orange  Santa Ana Unified
# 3     30  66670    0000  0116582  30666700116582  Orange  Santa Ana Unified
# 4     30  66670    0000  0135897  30666700135897  Orange  Santa Ana Unified
# 5     30  66670    0000  3030491  30666703030491  Orange  Santa Ana Unified
# 6     30  66670    0000  3030608  30666703030608  Orange  Santa Ana Unified
# 7     30  66670    0000  3035821  30666703035821  Orange  Santa Ana Unified
# 8     30  66670    0000  3036357  30666703036357  Orange  Santa Ana Unified
# 9     30  66670    0000  3036456  30666703036456  Orange  Santa Ana Unified
# 10    30  66670    0000  6030209  30666706030209  Orange  Santa Ana Unified
# ...

# %%
research_14_sna_ac_5 = research_14_sna_ac_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_14','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_14','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_5 = pandas.merge(sna_ac_5, research_14_sna_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
sna_ac_5
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County           District  \
# 0     30  66670    0000  0108365  30666700108365  Orange  Santa Ana Unified
# 1     30  66670    0000  0108373  30666700108373  Orange  Santa Ana Unified
# 2     30  66670    0000  0114736  30666700114736  Orange  Santa Ana Unified
# 3     30  66670    0000  0116582  30666700116582  Orange  Santa Ana Unified
# 4     30  66670    0000  0135897  30666700135897  Orange  Santa Ana Unified
# 5     30  66670    0000  3030491  30666703030491  Orange  Santa Ana Unified
# 6     30  66670    0000  3030608  30666703030608  Orange  Santa Ana Unified
# 7     30  66670    0000  3035821  30666703035821  Orange  Santa Ana Unified
# 8     30  66670    0000  3036357  30666703036357  Orange  Santa Ana Unified
# 9     30  66670    0000  3036456  30666703036456  Orange  Santa Ana Unified
# 10    30  66670    0000  6030209  30666706030209  Orange  Santa Ana Unified
# ...

# %%
research_13_sna_ac_5 = research_13_sna_ac_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_13','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_13','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_5 = pandas.merge(sna_ac_5, research_13_sna_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
sna_ac_5
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County           District  \
# 0     30  66670    0000  0108365  30666700108365  Orange  Santa Ana Unified
# 1     30  66670    0000  0108373  30666700108373  Orange  Santa Ana Unified
# 2     30  66670    0000  0114736  30666700114736  Orange  Santa Ana Unified
# 3     30  66670    0000  0116582  30666700116582  Orange  Santa Ana Unified
# 4     30  66670    0000  0135897  30666700135897  Orange  Santa Ana Unified
# 5     30  66670    0000  3030491  30666703030491  Orange  Santa Ana Unified
# 6     30  66670    0000  3030608  30666703030608  Orange  Santa Ana Unified
# 7     30  66670    0000  3035821  30666703035821  Orange  Santa Ana Unified
# 8     30  66670    0000  3036357  30666703036357  Orange  Santa Ana Unified
# 9     30  66670    0000  3036456  30666703036456  Orange  Santa Ana Unified
# 10    30  66670    0000  6030209  30666706030209  Orange  Santa Ana Unified
# ...

# %%
research_12_sna_ac_5 = research_12_sna_ac_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_12','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_12','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_5 = pandas.merge(sna_ac_5, research_12_sna_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
sna_ac_5
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County           District  \
# 0     30  66670    0000  0108365  30666700108365  Orange  Santa Ana Unified
# 1     30  66670    0000  0108373  30666700108373  Orange  Santa Ana Unified
# 2     30  66670    0000  0114736  30666700114736  Orange  Santa Ana Unified
# 3     30  66670    0000  0116582  30666700116582  Orange  Santa Ana Unified
# 4     30  66670    0000  0135897  30666700135897  Orange  Santa Ana Unified
# 5     30  66670    0000  3030491  30666703030491  Orange  Santa Ana Unified
# 6     30  66670    0000  3030608  30666703030608  Orange  Santa Ana Unified
# 7     30  66670    0000  3035821  30666703035821  Orange  Santa Ana Unified
# 8     30  66670    0000  3036357  30666703036357  Orange  Santa Ana Unified
# 9     30  66670    0000  3036456  30666703036456  Orange  Santa Ana Unified
# 10    30  66670    0000  6030209  30666706030209  Orange  Santa Ana Unified
# ...

# %%
research_11_sna_ac_5 = research_11_sna_ac_5.drop(columns=['ID','Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_11','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_11','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_5 = pandas.merge(sna_ac_5, research_11_sna_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
sna_ac_5
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County           District  \
# 0     30  66670    0000  0108365  30666700108365  Orange  Santa Ana Unified
# 1     30  66670    0000  0108373  30666700108373  Orange  Santa Ana Unified
# 2     30  66670    0000  0114736  30666700114736  Orange  Santa Ana Unified
# 3     30  66670    0000  0116582  30666700116582  Orange  Santa Ana Unified
# 4     30  66670    0000  0135897  30666700135897  Orange  Santa Ana Unified
# 5     30  66670    0000  3030491  30666703030491  Orange  Santa Ana Unified
# 6     30  66670    0000  3030608  30666703030608  Orange  Santa Ana Unified
# 7     30  66670    0000  3035821  30666703035821  Orange  Santa Ana Unified
# 8     30  66670    0000  3036357  30666703036357  Orange  Santa Ana Unified
# 9     30  66670    0000  3036456  30666703036456  Orange  Santa Ana Unified
# 10    30  66670    0000  6030209  30666706030209  Orange  Santa Ana Unified
# ...

# %%
sna_ac_5.to_csv("sna_ac_5_outliers.csv")

# %%
sna_ac_7 = pandas.merge(entities_sna, research_19_sna_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
sna_ac_7 = sna_ac_7.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_19','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_19','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])

research_18_sna_ac_7 = research_18_sna_ac_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_18','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_18','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_7 = pandas.merge(sna_ac_7, research_18_sna_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

# %%
research_17_sna_ac_7 = research_17_sna_ac_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_17','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_17','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_7 = pandas.merge(sna_ac_7, research_17_sna_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_16_sna_ac_7 = research_16_sna_ac_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_16','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_16','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_7 = pandas.merge(sna_ac_7, research_16_sna_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_15_sna_ac_7 = research_15_sna_ac_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_15','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_15','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_7 = pandas.merge(sna_ac_7, research_15_sna_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_14_sna_ac_7 = research_14_sna_ac_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_14','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_14','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_7 = pandas.merge(sna_ac_7, research_14_sna_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_13_sna_ac_7 = research_13_sna_ac_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_13','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_13','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_7 = pandas.merge(sna_ac_7, research_13_sna_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_12_sna_ac_7 = research_12_sna_ac_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_12','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_12','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_7 = pandas.merge(sna_ac_7, research_12_sna_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_11_sna_ac_7 = research_11_sna_ac_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_11','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_11','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number', 'ID'])
sna_ac_7 = pandas.merge(sna_ac_7, research_11_sna_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

sna_ac_7
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County           District  \
# 0     30  66670    0000  0108365  30666700108365  Orange  Santa Ana Unified
# 1     30  66670    0000  0108373  30666700108373  Orange  Santa Ana Unified
# 2     30  66670    0000  0114736  30666700114736  Orange  Santa Ana Unified
# 3     30  66670    0000  0116582  30666700116582  Orange  Santa Ana Unified
# 4     30  66670    0000  0135897  30666700135897  Orange  Santa Ana Unified
# 5     30  66670    0000  3030491  30666703030491  Orange  Santa Ana Unified
# 6     30  66670    0000  3030608  30666703030608  Orange  Santa Ana Unified
# 7     30  66670    0000  3035821  30666703035821  Orange  Santa Ana Unified
# 8     30  66670    0000  3036357  30666703036357  Orange  Santa Ana Unified
# 9     30  66670    0000  3036456  30666703036456  Orange  Santa Ana Unified
# 10    30  66670    0000  6030209  30666706030209  Orange  Santa Ana Unified
# ...

# %%
sna_ac_7.to_csv("sna_ac_7_outliers.csv")

# %%
sna_ac_9 = pandas.merge(entities_sna, research_19_sna_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
sna_ac_9 = sna_ac_9.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_19','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_19','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])

research_18_sna_ac_9 = research_18_sna_ac_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_18','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_18','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_9 = pandas.merge(sna_ac_9, research_18_sna_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_17_sna_ac_9 = research_17_sna_ac_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_17','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_17','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_9 = pandas.merge(sna_ac_9, research_17_sna_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_16_sna_ac_9 = research_16_sna_ac_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_16','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_16','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_9 = pandas.merge(sna_ac_9, research_16_sna_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_15_sna_ac_9 = research_15_sna_ac_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_15','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_15','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_9 = pandas.merge(sna_ac_9, research_15_sna_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_14_sna_ac_9 = research_14_sna_ac_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_14','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_14','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_9 = pandas.merge(sna_ac_9, research_14_sna_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_13_sna_ac_9 = research_13_sna_ac_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_13','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_13','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_9 = pandas.merge(sna_ac_9, research_13_sna_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_12_sna_ac_9 = research_12_sna_ac_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_12','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_12','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_ac_9 = pandas.merge(sna_ac_9, research_12_sna_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_11_sna_ac_9 = research_11_sna_ac_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_11','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_11','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number', 'ID'])
sna_ac_9 = pandas.merge(sna_ac_9, research_11_sna_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

sna_ac_9
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County           District  \
# 0     30  66670    0000  0108365  30666700108365  Orange  Santa Ana Unified
# 1     30  66670    0000  0108373  30666700108373  Orange  Santa Ana Unified
# 2     30  66670    0000  0114736  30666700114736  Orange  Santa Ana Unified
# 3     30  66670    0000  0116582  30666700116582  Orange  Santa Ana Unified
# 4     30  66670    0000  0135897  30666700135897  Orange  Santa Ana Unified
# 5     30  66670    0000  3030491  30666703030491  Orange  Santa Ana Unified
# 6     30  66670    0000  3030608  30666703030608  Orange  Santa Ana Unified
# 7     30  66670    0000  3035821  30666703035821  Orange  Santa Ana Unified
# 8     30  66670    0000  3036357  30666703036357  Orange  Santa Ana Unified
# 9     30  66670    0000  3036456  30666703036456  Orange  Santa Ana Unified
# 10    30  66670    0000  6030209  30666706030209  Orange  Santa Ana Unified
# ...

# %%
sna_ac_9.to_csv('sna_ac_9_outliers.csv')

# %%
# sna_bc = pandas.merge(entities_sna, research_19_sna_bc, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
# sna_bc = sna_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# sna_bc = pandas.merge(sna_bc, research_18_sna_bc, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# sna_bc = sna_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# sna_bc = pandas.merge(sna_bc, research_17_sna_bc, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# sna_bc = sna_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# sna_bc = pandas.merge(sna_bc, research_16_sna_bc, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# sna_bc = sna_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# sna_bc = pandas.merge(sna_bc, research_15_sna_bc, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# sna_bc = sna_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# sna_bc = pandas.merge(sna_bc, research_14_sna_bc, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# sna_bc = sna_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# sna_bc = pandas.merge(sna_bc, research_13_sna_bc, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# sna_bc = sna_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# sna_bc = pandas.merge(sna_bc, research_12_sna_bc, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# sna_bc = sna_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# sna_bc = pandas.merge(sna_bc, research_11_sna_bc, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# sna_bc = sna_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number','ID'])
# sna_bc

# %%
sna_bc_5 = pandas.merge(entities_sna, research_19_sna_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
sna_bc_5 = sna_bc_5.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_19','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_19','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])

research_18_sna_bc_5 = research_18_sna_bc_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_18','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_18','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_5 = pandas.merge(sna_bc_5, research_18_sna_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_17_sna_bc_5 = research_17_sna_bc_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_17','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_17','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_5 = pandas.merge(sna_bc_5, research_17_sna_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_16_sna_bc_5 = research_16_sna_bc_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_16','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_16','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_5 = pandas.merge(sna_bc_5, research_16_sna_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_15_sna_bc_5 = research_15_sna_bc_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_15','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_15','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_5 = pandas.merge(sna_bc_5, research_15_sna_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_14_sna_bc_5 = research_14_sna_bc_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_14','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_14','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_5 = pandas.merge(sna_bc_5, research_14_sna_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_13_sna_bc_5 = research_13_sna_bc_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_13','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_13','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_5 = pandas.merge(sna_bc_5, research_13_sna_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_12_sna_bc_5 = research_12_sna_bc_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_12','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_12','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_5 = pandas.merge(sna_bc_5, research_12_sna_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_11_sna_bc_5 = research_11_sna_bc_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_11','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_11','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number', 'ID'])
sna_bc_5 = pandas.merge(sna_bc_5, research_11_sna_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

sna_bc_5
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County           District  \
# 0     30  66670    0000  0108365  30666700108365  Orange  Santa Ana Unified
# 1     30  66670    0000  0108373  30666700108373  Orange  Santa Ana Unified
# 2     30  66670    0000  0114736  30666700114736  Orange  Santa Ana Unified
# 3     30  66670    0000  0116582  30666700116582  Orange  Santa Ana Unified
# 4     30  66670    0000  0135897  30666700135897  Orange  Santa Ana Unified
# 5     30  66670    0000  3030491  30666703030491  Orange  Santa Ana Unified
# 6     30  66670    0000  3030608  30666703030608  Orange  Santa Ana Unified
# 7     30  66670    0000  3035821  30666703035821  Orange  Santa Ana Unified
# 8     30  66670    0000  3036357  30666703036357  Orange  Santa Ana Unified
# 9     30  66670    0000  3036456  30666703036456  Orange  Santa Ana Unified
# 10    30  66670    0000  6030209  30666706030209  Orange  Santa Ana Unified
# ...

# %%
sna_bc_7 = pandas.merge(entities_sna, research_19_sna_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
sna_bc_7 = sna_bc_7.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_19','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_19','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])

research_18_sna_bc_7 = research_18_sna_bc_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_18','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_18','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_7 = pandas.merge(sna_bc_7, research_18_sna_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_17_sna_bc_7 = research_17_sna_bc_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_17','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_17','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_7 = pandas.merge(sna_bc_7, research_17_sna_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_16_sna_bc_7 = research_16_sna_bc_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_16','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_16','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_7 = pandas.merge(sna_bc_7, research_16_sna_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_15_sna_bc_7 = research_15_sna_bc_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_15','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_15','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_7 = pandas.merge(sna_bc_7, research_15_sna_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_14_sna_bc_7 = research_14_sna_bc_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_14','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_14','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_7 = pandas.merge(sna_bc_7, research_14_sna_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_13_sna_bc_7 = research_13_sna_bc_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_13','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_13','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_7 = pandas.merge(sna_bc_7, research_13_sna_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_12_sna_bc_7 = research_12_sna_bc_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_12','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_12','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_7 = pandas.merge(sna_bc_7, research_12_sna_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_11_sna_bc_7 = research_11_sna_bc_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_11','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_11','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number', 'ID'])
sna_bc_7 = pandas.merge(sna_bc_7, research_11_sna_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

sna_bc_7
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County           District  \
# 0     30  66670    0000  0108365  30666700108365  Orange  Santa Ana Unified
# 1     30  66670    0000  0108373  30666700108373  Orange  Santa Ana Unified
# 2     30  66670    0000  0114736  30666700114736  Orange  Santa Ana Unified
# 3     30  66670    0000  0116582  30666700116582  Orange  Santa Ana Unified
# 4     30  66670    0000  0135897  30666700135897  Orange  Santa Ana Unified
# 5     30  66670    0000  3030491  30666703030491  Orange  Santa Ana Unified
# 6     30  66670    0000  3030608  30666703030608  Orange  Santa Ana Unified
# 7     30  66670    0000  3035821  30666703035821  Orange  Santa Ana Unified
# 8     30  66670    0000  3036357  30666703036357  Orange  Santa Ana Unified
# 9     30  66670    0000  3036456  30666703036456  Orange  Santa Ana Unified
# 10    30  66670    0000  6030209  30666706030209  Orange  Santa Ana Unified
# ...

# %%
sna_bc_9 = pandas.merge(entities_sna, research_19_sna_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
sna_bc_9 = sna_bc_9.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_19','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_19','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])

research_18_sna_bc_9 = research_18_sna_bc_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_18','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_18','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_9 = pandas.merge(sna_bc_9, research_18_sna_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_17_sna_bc_9 = research_17_sna_bc_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_17','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_17','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_9 = pandas.merge(sna_bc_9, research_17_sna_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_16_sna_bc_9 = research_16_sna_bc_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_16','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_16','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_9 = pandas.merge(sna_bc_9, research_16_sna_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_15_sna_bc_9 = research_15_sna_bc_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_15','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_15','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_9 = pandas.merge(sna_bc_9, research_15_sna_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_14_sna_bc_9 = research_14_sna_bc_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_14','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_14','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_9 = pandas.merge(sna_bc_9, research_14_sna_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_13_sna_bc_9 = research_13_sna_bc_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_13','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_13','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_9 = pandas.merge(sna_bc_9, research_13_sna_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_12_sna_bc_9 = research_12_sna_bc_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_12','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_12','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
sna_bc_9 = pandas.merge(sna_bc_9, research_12_sna_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_11_sna_bc_9 = research_11_sna_bc_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_11','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_11','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number', 'ID'])
sna_bc_9 = pandas.merge(sna_bc_9, research_11_sna_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

sna_bc_9
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County           District  \
# 0     30  66670    0000  0108365  30666700108365  Orange  Santa Ana Unified
# 1     30  66670    0000  0108373  30666700108373  Orange  Santa Ana Unified
# 2     30  66670    0000  0114736  30666700114736  Orange  Santa Ana Unified
# 3     30  66670    0000  0116582  30666700116582  Orange  Santa Ana Unified
# 4     30  66670    0000  0135897  30666700135897  Orange  Santa Ana Unified
# 5     30  66670    0000  3030491  30666703030491  Orange  Santa Ana Unified
# 6     30  66670    0000  3030608  30666703030608  Orange  Santa Ana Unified
# 7     30  66670    0000  3035821  30666703035821  Orange  Santa Ana Unified
# 8     30  66670    0000  3036357  30666703036357  Orange  Santa Ana Unified
# 9     30  66670    0000  3036456  30666703036456  Orange  Santa Ana Unified
# 10    30  66670    0000  6030209  30666706030209  Orange  Santa Ana Unified
# ...

# %%
sna_bc_5.to_csv("sna_bc_5_outliers.csv")
sna_bc_7.to_csv("sna_bc_7_outliers.csv")
sna_bc_9.to_csv("sna_bc_9_outliers.csv")

# %%
irv_ac_5 = pandas.merge(entities_irv, research_19_irv_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
irv_ac_5 = irv_ac_5.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_19','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_19','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])

research_18_irv_ac_5 = research_18_irv_ac_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_18','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_18','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_5 = pandas.merge(irv_ac_5, research_18_irv_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_17_irv_ac_5 = research_17_irv_ac_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_17','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_17','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_5 = pandas.merge(irv_ac_5, research_17_irv_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_16_irv_ac_5 = research_16_irv_ac_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_16','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_16','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_5 = pandas.merge(irv_ac_5, research_16_irv_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_15_irv_ac_5 = research_15_irv_ac_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_15','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_15','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_5 = pandas.merge(irv_ac_5, research_15_irv_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_14_irv_ac_5 = research_14_irv_ac_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_14','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_14','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_5 = pandas.merge(irv_ac_5, research_14_irv_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_13_irv_ac_5 = research_13_irv_ac_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_13','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_13','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_5 = pandas.merge(irv_ac_5, research_13_irv_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_12_irv_ac_5 = research_12_irv_ac_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_12','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_12','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_5 = pandas.merge(irv_ac_5, research_12_irv_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_11_irv_ac_5 = research_11_irv_ac_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_11','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_11','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number', 'ID'])
irv_ac_5 = pandas.merge(irv_ac_5, research_11_irv_ac_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

irv_ac_5
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County        District  \
# 0     30  73650    0000  0127472  30736500127472  Orange  Irvine Unified
# 1     30  73650    0000  0129155  30736500129155  Orange  Irvine Unified
# 2     30  73650    0000  0129296  30736500129296  Orange  Irvine Unified
# 3     30  73650    0000  0133389  30736500133389  Orange  Irvine Unified
# 4     30  73650    0000  0133405  30736500133405  Orange  Irvine Unified
# 5     30  73650    0000  0135137  30736500135137  Orange  Irvine Unified
# 6     30  73650    0000  0136689  30736500136689  Orange  Irvine Unified
# 7     30  73650    0000  3030152  30736503030152  Orange  Irvine Unified
# 8     30  73650    0000  3030285  30736503030285  Orange  Irvine Unified
# 9     30  73650    0000  3030467  30736503030467  Orange  Irvine Unified
# 10    30  73650    0000  3030657  30736503030657  Orange  Irvine Unified
# 11    30  73650    0000  3035102  30736503035102  Orange  Irvine Unified
# ...

# %%
irv_ac_7 = pandas.merge(entities_irv, research_19_irv_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
irv_ac_7 = irv_ac_7.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_19','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_19','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])

research_18_irv_ac_7 = research_18_irv_ac_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_18','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_18','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_7 = pandas.merge(irv_ac_7, research_18_irv_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_17_irv_ac_7 = research_17_irv_ac_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_17','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_17','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_7 = pandas.merge(irv_ac_7, research_17_irv_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_16_irv_ac_7 = research_16_irv_ac_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_16','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_16','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_7 = pandas.merge(irv_ac_7, research_16_irv_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_15_irv_ac_7 = research_15_irv_ac_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_15','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_15','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_7 = pandas.merge(irv_ac_7, research_15_irv_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_14_irv_ac_7 = research_14_irv_ac_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_14','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_14','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_7 = pandas.merge(irv_ac_7, research_14_irv_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_13_irv_ac_7 = research_13_irv_ac_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_13','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_13','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_7 = pandas.merge(irv_ac_7, research_13_irv_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_12_irv_ac_7 = research_12_irv_ac_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_12','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_12','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_7 = pandas.merge(irv_ac_7, research_12_irv_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_11_irv_ac_7 = research_11_irv_ac_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_11','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_11','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number', 'ID'])
irv_ac_7 = pandas.merge(irv_ac_7, research_11_irv_ac_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

irv_ac_7
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County        District  \
# 0     30  73650    0000  0127472  30736500127472  Orange  Irvine Unified
# 1     30  73650    0000  0129155  30736500129155  Orange  Irvine Unified
# 2     30  73650    0000  0129296  30736500129296  Orange  Irvine Unified
# 3     30  73650    0000  0133389  30736500133389  Orange  Irvine Unified
# 4     30  73650    0000  0133405  30736500133405  Orange  Irvine Unified
# 5     30  73650    0000  0135137  30736500135137  Orange  Irvine Unified
# 6     30  73650    0000  0136689  30736500136689  Orange  Irvine Unified
# 7     30  73650    0000  3030152  30736503030152  Orange  Irvine Unified
# 8     30  73650    0000  3030285  30736503030285  Orange  Irvine Unified
# 9     30  73650    0000  3030467  30736503030467  Orange  Irvine Unified
# 10    30  73650    0000  3030657  30736503030657  Orange  Irvine Unified
# 11    30  73650    0000  3035102  30736503035102  Orange  Irvine Unified
# ...

# %%
irv_ac_9 = pandas.merge(entities_irv, research_19_irv_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
irv_ac_9 = irv_ac_9.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_19','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_19','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])

research_18_irv_ac_9 = research_18_irv_ac_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_18','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_18','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_9 = pandas.merge(irv_ac_9, research_18_irv_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_17_irv_ac_9 = research_17_irv_ac_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_17','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_17','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_9 = pandas.merge(irv_ac_9, research_17_irv_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_16_irv_ac_9 = research_16_irv_ac_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_16','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_16','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_9 = pandas.merge(irv_ac_9, research_16_irv_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_15_irv_ac_9 = research_15_irv_ac_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_15','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_15','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_9 = pandas.merge(irv_ac_9, research_15_irv_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_14_irv_ac_9 = research_14_irv_ac_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_14','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_14','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_9 = pandas.merge(irv_ac_9, research_14_irv_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_13_irv_ac_9 = research_13_irv_ac_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_13','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_13','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_9 = pandas.merge(irv_ac_9, research_13_irv_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_12_irv_ac_9 = research_12_irv_ac_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_12','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_12','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_ac_9 = pandas.merge(irv_ac_9, research_12_irv_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_11_irv_ac_9 = research_11_irv_ac_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_11','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_11','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number', 'ID'])
irv_ac_9 = pandas.merge(irv_ac_9, research_11_irv_ac_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

irv_ac_9
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County        District  \
# 0     30  73650    0000  0127472  30736500127472  Orange  Irvine Unified
# 1     30  73650    0000  0129155  30736500129155  Orange  Irvine Unified
# 2     30  73650    0000  0129296  30736500129296  Orange  Irvine Unified
# 3     30  73650    0000  0133389  30736500133389  Orange  Irvine Unified
# 4     30  73650    0000  0133405  30736500133405  Orange  Irvine Unified
# 5     30  73650    0000  0135137  30736500135137  Orange  Irvine Unified
# 6     30  73650    0000  0136689  30736500136689  Orange  Irvine Unified
# 7     30  73650    0000  3030152  30736503030152  Orange  Irvine Unified
# 8     30  73650    0000  3030285  30736503030285  Orange  Irvine Unified
# 9     30  73650    0000  3030467  30736503030467  Orange  Irvine Unified
# 10    30  73650    0000  3030657  30736503030657  Orange  Irvine Unified
# 11    30  73650    0000  3035102  30736503035102  Orange  Irvine Unified
# ...

# %%
irv_ac_5.to_csv("irv_ac_5_outliers.csv")
irv_ac_7.to_csv("irv_ac_7_outliers.csv")
irv_ac_9.to_csv("irv_ac_9_outliers.csv")

# %%
irv_bc_5 = pandas.merge(entities_irv, research_19_irv_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
irv_bc_5 = irv_bc_5.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_19','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_19','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])

research_18_irv_bc_5 = research_18_irv_bc_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_18','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_18','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_5 = pandas.merge(irv_bc_5, research_18_irv_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_17_irv_bc_5 = research_17_irv_bc_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_17','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_17','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_5 = pandas.merge(irv_bc_5, research_17_irv_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_16_irv_bc_5 = research_16_irv_bc_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_16','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_16','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_5 = pandas.merge(irv_bc_5, research_16_irv_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_15_irv_bc_5 = research_15_irv_bc_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_15','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_15','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_5 = pandas.merge(irv_bc_5, research_15_irv_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_14_irv_bc_5 = research_14_irv_bc_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_14','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_14','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_5 = pandas.merge(irv_bc_5, research_14_irv_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_13_irv_bc_5 = research_13_irv_bc_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_13','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_13','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_5 = pandas.merge(irv_bc_5, research_13_irv_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_12_irv_bc_5 = research_12_irv_bc_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_12','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_12','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_5 = pandas.merge(irv_bc_5, research_12_irv_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_11_irv_bc_5 = research_11_irv_bc_5.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7a_11','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_11','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number', 'ID'])
irv_bc_5 = pandas.merge(irv_bc_5, research_11_irv_bc_5, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

irv_bc_5
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County        District  \
# 0     30  73650    0000  0127472  30736500127472  Orange  Irvine Unified
# 1     30  73650    0000  0129155  30736500129155  Orange  Irvine Unified
# 2     30  73650    0000  0129296  30736500129296  Orange  Irvine Unified
# 3     30  73650    0000  0133389  30736500133389  Orange  Irvine Unified
# 4     30  73650    0000  0133405  30736500133405  Orange  Irvine Unified
# 5     30  73650    0000  0135137  30736500135137  Orange  Irvine Unified
# 6     30  73650    0000  0136689  30736500136689  Orange  Irvine Unified
# 7     30  73650    0000  3030152  30736503030152  Orange  Irvine Unified
# 8     30  73650    0000  3030285  30736503030285  Orange  Irvine Unified
# 9     30  73650    0000  3030467  30736503030467  Orange  Irvine Unified
# 10    30  73650    0000  3030657  30736503030657  Orange  Irvine Unified
# 11    30  73650    0000  3035102  30736503035102  Orange  Irvine Unified
# ...

# %%
irv_bc_7 = pandas.merge(entities_irv, research_19_irv_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
irv_bc_7 = irv_bc_7.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_19','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_19','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])

research_18_irv_bc_7 = research_18_irv_bc_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_18','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_18','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_7 = pandas.merge(irv_bc_7, research_18_irv_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_17_irv_bc_7 = research_17_irv_bc_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_17','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_17','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_7 = pandas.merge(irv_bc_7, research_17_irv_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_16_irv_bc_7 = research_16_irv_bc_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_16','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_16','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_7 = pandas.merge(irv_bc_7, research_16_irv_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_15_irv_bc_7 = research_15_irv_bc_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_15','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_15','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_7 = pandas.merge(irv_bc_7, research_15_irv_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_14_irv_bc_7 = research_14_irv_bc_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_14','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_14','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_7 = pandas.merge(irv_bc_7, research_14_irv_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_13_irv_bc_7 = research_13_irv_bc_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_13','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_13','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_7 = pandas.merge(irv_bc_7, research_13_irv_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_12_irv_bc_7 = research_12_irv_bc_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_12','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_12','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_7 = pandas.merge(irv_bc_7, research_12_irv_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_11_irv_bc_7 = research_11_irv_bc_7.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_11','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9a_11','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number', 'ID'])
irv_bc_7 = pandas.merge(irv_bc_7, research_11_irv_bc_7, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

irv_bc_7
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County        District  \
# 0     30  73650    0000  0127472  30736500127472  Orange  Irvine Unified
# 1     30  73650    0000  0129155  30736500129155  Orange  Irvine Unified
# 2     30  73650    0000  0129296  30736500129296  Orange  Irvine Unified
# 3     30  73650    0000  0133389  30736500133389  Orange  Irvine Unified
# 4     30  73650    0000  0133405  30736500133405  Orange  Irvine Unified
# 5     30  73650    0000  0135137  30736500135137  Orange  Irvine Unified
# 6     30  73650    0000  0136689  30736500136689  Orange  Irvine Unified
# 7     30  73650    0000  3030152  30736503030152  Orange  Irvine Unified
# 8     30  73650    0000  3030285  30736503030285  Orange  Irvine Unified
# 9     30  73650    0000  3030467  30736503030467  Orange  Irvine Unified
# 10    30  73650    0000  3030657  30736503030657  Orange  Irvine Unified
# 11    30  73650    0000  3035102  30736503035102  Orange  Irvine Unified
# ...

# %%
irv_bc_9 = pandas.merge(entities_irv, research_19_irv_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
irv_bc_9 = irv_bc_9.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_19','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_19','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])

research_18_irv_bc_9 = research_18_irv_bc_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_18','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_18','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_9 = pandas.merge(irv_bc_9, research_18_irv_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_17_irv_bc_9 = research_17_irv_bc_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_17','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_17','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_9 = pandas.merge(irv_bc_9, research_17_irv_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_16_irv_bc_9 = research_16_irv_bc_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_16','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_16','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_9 = pandas.merge(irv_bc_9, research_16_irv_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_15_irv_bc_9 = research_15_irv_bc_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_15','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_15','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_9 = pandas.merge(irv_bc_9, research_15_irv_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_14_irv_bc_9 = research_14_irv_bc_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_14','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_14','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_9 = pandas.merge(irv_bc_9, research_14_irv_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_13_irv_bc_9 = research_13_irv_bc_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_13','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_13','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_9 = pandas.merge(irv_bc_9, research_13_irv_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_12_irv_bc_9 = research_12_irv_bc_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_12','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_12','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
irv_bc_9 = pandas.merge(irv_bc_9, research_12_irv_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

research_11_irv_bc_9 = research_11_irv_bc_9.drop(columns=['Line_Text', 'NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc5a_11','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc7a_11','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number', 'ID'])
irv_bc_9 = pandas.merge(irv_bc_9, research_11_irv_bc_9, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')

irv_bc_9
# Out:
#    ccode  dcode chrtnum    scode         cdscode  County        District  \
# 0     30  73650    0000  0127472  30736500127472  Orange  Irvine Unified
# 1     30  73650    0000  0129155  30736500129155  Orange  Irvine Unified
# 2     30  73650    0000  0129296  30736500129296  Orange  Irvine Unified
# 3     30  73650    0000  0133389  30736500133389  Orange  Irvine Unified
# 4     30  73650    0000  0133405  30736500133405  Orange  Irvine Unified
# 5     30  73650    0000  0135137  30736500135137  Orange  Irvine Unified
# 6     30  73650    0000  0136689  30736500136689  Orange  Irvine Unified
# 7     30  73650    0000  3030152  30736503030152  Orange  Irvine Unified
# 8     30  73650    0000  3030285  30736503030285  Orange  Irvine Unified
# 9     30  73650    0000  3030467  30736503030467  Orange  Irvine Unified
# 10    30  73650    0000  3030657  30736503030657  Orange  Irvine Unified
# 11    30  73650    0000  3035102  30736503035102  Orange  Irvine Unified
# ...

# %%
irv_bc_5.to_csv('irv_bc_5_outliers.csv')
irv_bc_7.to_csv('irv_bc_7_outliers.csv')
irv_bc_9.to_csv('irv_bc_9_outliers.csv')

# %%
# irv_ac = pandas.merge(entities_irv, research_19_irv_ac, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
# irv_ac = irv_ac.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# irv_ac = pandas.merge(irv_ac, research_18_irv_ac, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# irv_ac = irv_ac.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# irv_ac = pandas.merge(irv_ac, research_17_irv_ac, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# irv_ac = irv_ac.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# irv_ac = pandas.merge(irv_ac, research_16_irv_ac, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# irv_ac = irv_ac.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# irv_ac = pandas.merge(irv_ac, research_15_irv_ac, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# irv_ac = irv_ac.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# irv_ac = pandas.merge(irv_ac, research_14_irv_ac, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# irv_ac = irv_ac.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# irv_ac = pandas.merge(irv_ac, research_13_irv_ac, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# irv_ac = irv_ac.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# irv_ac = pandas.merge(irv_ac, research_12_irv_ac, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# irv_ac = irv_ac.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# irv_ac = pandas.merge(irv_ac, research_11_irv_ac, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# irv_ac = irv_ac.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number','ID'])
# irv_ac

# %%
# irv_ac_5 = irv_ac.drop(columns=['Perc7a_19','Perc7a_18','Perc7a_17','Perc7a_16','Perc7a_15','Perc7a_14','Perc7a_13','Perc7a_12','Perc7a_11','Perc9a_19','Perc9a_18','Perc9a_17','Perc9a_16','Perc9a_15','Perc9a_14','Perc9a_13','Perc9a_12','Perc9a_11'])
# irv_ac_7 = irv_ac.drop(columns=['Perc5a_19','Perc5a_18','Perc5a_17','Perc5a_16','Perc5a_15','Perc5a_14','Perc5a_13','Perc5a_12','Perc5a_11','Perc9a_19','Perc9a_18','Perc9a_17','Perc9a_16','Perc9a_15','Perc9a_14','Perc9a_13','Perc9a_12','Perc9a_11'])
# irv_ac_9 = irv_ac.drop(columns=['Perc7a_19','Perc7a_18','Perc7a_17','Perc7a_16','Perc7a_15','Perc7a_14','Perc7a_13','Perc7a_12','Perc7a_11','Perc5a_19','Perc5a_18','Perc5a_17','Perc5a_16','Perc5a_15','Perc5a_14','Perc5a_13','Perc5a_12','Perc5a_11'])
# irv_ac_5.to_csv('irv_ac_5.csv')
# irv_ac_7.to_csv('irv_ac_7.csv')
# irv_ac_9.to_csv('irv_ac_9.csv')

# %%
# irv_bc = pandas.merge(entities_irv, research_19_irv_bc, left_on=['ccode','dcode','scode','chrtnum'], right_on=['ccode','dcode','scode','chrtnum'], how='outer')
# irv_bc = irv_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# irv_bc = pandas.merge(irv_bc, research_18_irv_bc, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# irv_bc = irv_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# irv_bc = pandas.merge(irv_bc, research_17_irv_bc, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# irv_bc = irv_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# irv_bc = pandas.merge(irv_bc, research_16_irv_bc, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# irv_bc = irv_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# irv_bc = pandas.merge(irv_bc, research_15_irv_bc, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# irv_bc = irv_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# irv_bc = pandas.merge(irv_bc, research_14_irv_bc, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# irv_bc = irv_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# irv_bc = pandas.merge(irv_bc, research_13_irv_bc, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# irv_bc = irv_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# irv_bc = pandas.merge(irv_bc, research_12_irv_bc, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# irv_bc = irv_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number'])
# irv_bc = pandas.merge(irv_bc, research_11_irv_bc, left_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], right_on=['ccode','dcode','scode','chrtnum', 'Line_Text'], how='outer')
# irv_bc = irv_bc.drop(columns=['NoStud5','NoHFZ5','Perc5b','Perc5c','NoStud7','NoHFZ7','Perc7b','Perc7c','NoStud9','NoHFZ9','Perc9b','Perc9c','Level_Number','Report_Number','Table_Number','Line_Number','ID'])
# irv_bc

# %%
# irv_bc_5 = irv_bc.drop(columns=['Perc7a_19','Perc7a_18','Perc7a_17','Perc7a_16','Perc7a_15','Perc7a_14','Perc7a_13','Perc7a_12','Perc7a_11','Perc9a_19','Perc9a_18','Perc9a_17','Perc9a_16','Perc9a_15','Perc9a_14','Perc9a_13','Perc9a_12','Perc9a_11'])
# irv_bc_7 = irv_bc.drop(columns=['Perc5a_19','Perc5a_18','Perc5a_17','Perc5a_16','Perc5a_15','Perc5a_14','Perc5a_13','Perc5a_12','Perc5a_11','Perc9a_19','Perc9a_18','Perc9a_17','Perc9a_16','Perc9a_15','Perc9a_14','Perc9a_13','Perc9a_12','Perc9a_11'])
# irv_bc_9 = irv_bc.drop(columns=['Perc7a_19','Perc7a_18','Perc7a_17','Perc7a_16','Perc7a_15','Perc7a_14','Perc7a_13','Perc7a_12','Perc7a_11','Perc5a_19','Perc5a_18','Perc5a_17','Perc5a_16','Perc5a_15','Perc5a_14','Perc5a_13','Perc5a_12','Perc5a_11'])
# irv_bc_5.to_csv('irv_bc_5.csv')
# irv_bc_7.to_csv('irv_bc_7.csv')
# irv_bc_9.to_csv('irv_bc_9.csv')
